# %%
# !nvidia-smi
# Out:
# Sun Mar 29 08:59:42 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.08             Driver Version: 580.105.08     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   45C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install roboflow
# !pip install -U ultralytics
# !pip install ultralytics
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="dqJb8eGc4r2Em1upBUpa")
project = rf.workspace("subhams-workspace-rcrwh").project("indian-emergency-vehicles-reanp")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.4.31)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cu126)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.4.31)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cu126)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Requirement already satisfied: roboflow in /usr/local/lib/python3.12/dist-packages (1.2.16)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2026.1.4)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.0.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pillow-avif-plugin<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.5.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: pi-heif<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (4.61.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (3.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->roboflow) (3.4.4)
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 85.0%
# Version export complete for yolov8 format
# Downloading Dataset Version Zip in Indian-emergency-vehicles-1 to yolov8:: 100%|██████████| 842363/842363 [00:09<00:00, 88721.05it/s]
# Extracting Dataset Version Zip to Indian-emergency-vehicles-1 in yolov8:: 100%|██████████| 42763/42763 [00:04<00:00, 9038.42it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO
from IPython.display import Image

# %%
dataset.location
# Out:
# '/kaggle/working/Indian-emergency-vehicles-1'

# %%
from ultralytics import YOLO

# Use the working configuration I created
model = YOLO('yolov8n.pt')

# Train immediately
results = model.train(
    data="/kaggle/working/Indian-emergency-vehicles-1/data.yaml",
    epochs=100,
    batch=32,
    device=[0, 1],
    optimizer='MuSGD',
    # lr0=0.001
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 81.1MB/s 0.1s
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
#                                                       CUDA:1 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/Indian-emergency-vehicles-1/data.yaml, degrees=0.0, deterministic=True, device=0,1, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=MuSGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 16.8MB/s 0.0s
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,433 parameters, 3,011,417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# DDP: debug command /usr/bin/python3 -m torch.distributed.run --nproc_per_node 2 --master_port 45895 /root/.config/Ultralytics/DDP/_temp_uk2wacbn133448467597504.py
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
#                                                       CUDA:1 (Tesla T4, 14913MiB)
# Overriding model.yaml nc=80 with nc=3
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 71.8MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 840.8±310.6 MB/s, size: 28.5 KB)
# train: Scanning /kaggle/working/Indian-emergency-vehicles-1/train/labels... 20520 images, 93 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 20520/20520 1.3Kit/s 15.3s<0.1s
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000025_jpg.rf.228744e969fa15da4b7edd345aaa231d.jpg: 2 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000025_jpg.rf.2e02b61bb94e915e9c785f387129aaa4.jpg: 2 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000025_jpg.rf.650c42dbff73a4d26ff1260c6674b863.jpg: 2 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000025_jpg.rf.68dd5c31a5121c085fc37510fb1dd6a9.jpg: 2 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000025_jpg.rf.78b88d48a13f374270bef4215a7bd092.jpg: 2 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000025_jpg.rf.ab6736f1e9065a6330022e48baa583f7.jpg: 2 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000025_jpg.rf.abe1a3aad90d0d1ae567aa2bd25b4344.jpg: 2 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000025_jpg.rf.b886091b07d9ad97403beabc96f284e4.jpg: 2 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000025_jpg.rf.eca8d36ec4cc945575f49fc758e4d4cc.jpg: 2 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000025_jpg.rf.f268f951a2434136de5d88b7560ec3e3.jpg: 2 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000034_jpg.rf.14837e985bd34509ce59f3c9d63cb075.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000034_jpg.rf.252d72ee2fa1d112c8c2566d8fb0affe.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000034_jpg.rf.4b9258c629b8f2084d9dff38e9f6569d.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000034_jpg.rf.57b7f1dbe90830df289d2cdcb67c5302.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000034_jpg.rf.6227163fd8a831d2f4eb01ad326e3da7.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000034_jpg.rf.c20269c911071c85867eed182be42022.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000034_jpg.rf.cdae3d6b1df8bdfbc5b9bcbc7a34303f.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000034_jpg.rf.edee710c2677304c265c439fd6ce97ea.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000034_jpg.rf.f139fc678268b5c45daddc96853d665e.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000034_jpg.rf.f8aebe48ca622fd60b1cf71a7a984655.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000041_jpg.rf.387e281ec0db316b1c15c35a0ddc6543.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000041_jpg.rf.4008b6befb3bc6ceb22c76073bff42d5.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000041_jpg.rf.53799cfaa02f0edc4272163e457a9dcf.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000041_jpg.rf.7179a9e0e5128672bd2d2ea9c63f7d14.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000041_jpg.rf.91fd82ee10af8f6fa6388bf3de1850c9.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/000041_jpg.rf.9e5e04201c9a95bbbf50a57b0b83a2df.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/
jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/1_mp4-0000_jpg.rf.77e4f8dfbf3313994dcd7de38f4643ab.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/1_mp4-0000_jpg.rf.c11744c718e6a4bb6f1b4f584296ded4.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/1_mp4-0000_jpg.rf.c9d856143f79572c725dae3919a25bf7.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/1_mp4-0000_jpg.rf.cbada55ceafd4cd3692e411e10989f3b.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/1_mp4-0000_jpg.rf.d3d097f3ab3b64c193a573ebdae915ae.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/20220413071557_Fire_truck-1-_jpg.rf.3661c00228c698917590b89a5e42c3ae.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/20220413071557_Fire_truck-1-_jpg.rf.3eb674910856b680badfa6cd634a4625.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/20220413071557_Fire_truck-1-_jpg.rf.5905f75656270a9fb25f4378da523f36.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/20220413071557_Fire_truck-1-_jpg.rf.5d1c57152bffda948c8c3d15cb7c39a2.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/20220413071557_Fire_truck-1-_jpg.rf.6a63cecbf529ec0cffa18d39bac226d4.jpg: 1 duplicate labels removed
# train: /kaggle/working/Indian-emergency-vehicles-1/train/images/20220413071557_Fire_truck-1-_jpg.rf.744b7f07dd0d4abc7fc1a41e40913c03.jpg: 1 duplicate labels removed
# ...
#                    all        565        657      0.895      0.709      0.778      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      3.64G     0.8458     0.5594      1.088          9        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:26<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.5it/s 2.0s0.2s
#                    all        565        657        0.9      0.702      0.779      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      3.66G     0.8358     0.5457       1.09         14        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:27<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.4it/s 2.0s0.2s
#                    all        565        657        0.9      0.703      0.779      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      3.67G     0.8312     0.5466      1.087         18        640: 100% ━━━━━━━━━━━━ 642/642 3.0it/s 3:31<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.6it/s 1.9s0.2s
#                    all        565        657      0.901      0.706       0.78      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      3.69G      0.825     0.5376      1.083         14        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:27<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.6it/s 2.0s0.2s
#                    all        565        657      0.896      0.708       0.78      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100       3.7G      0.827     0.5386      1.083          7        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:27<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.5it/s 2.0s0.2s
#                    all        565        657        0.9      0.707       0.78      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      3.72G     0.8295     0.5411      1.086         10        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:27<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.5it/s 2.0s0.2s
#                    all        565        657      0.901      0.707       0.78      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      3.74G     0.8137      0.534      1.082          6        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:29<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 5.0it/s 1.8s0.2s
#                    all        565        657      0.899      0.707      0.779      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      3.76G     0.8176     0.5351      1.078         13        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:27<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.5it/s 2.0s0.2s
#                    all        565        657      0.897       0.71      0.779      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      3.77G     0.8041     0.5266      1.072          9        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:29<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.6it/s 2.0s0.2s
#                    all        565        657      0.896       0.71      0.778      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      3.79G     0.8056     0.5216      1.073         11        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:28<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.6it/s 1.9s0.2s
#                    all        565        657      0.898       0.71      0.778      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100       3.8G     0.8062     0.5166      1.067         10        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:27<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.6it/s 2.0s0.2s
#                    all        565        657      0.896      0.709      0.777      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      3.82G     0.7967     0.5104      1.069          9        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:27<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.5it/s 2.0s0.2s
#                    all        565        657      0.898      0.709      0.778      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      3.84G     0.8019     0.5108      1.072          8        640: 100% ━━━━━━━━━━━━ 642/642 3.0it/s 3:33<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.6it/s 1.9s0.2s
#                    all        565        657      0.899      0.706      0.776      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      3.86G     0.7886     0.5086      1.064          6        640: 100% ━━━━━━━━━━━━ 642/642 3.0it/s 3:32<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.4it/s 2.0s0.2s
#                    all        565        657      0.904      0.707       0.78      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      3.88G     0.8012     0.5127      1.068         18        640: 100% ━━━━━━━━━━━━ 642/642 3.0it/s 3:31<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.6it/s 2.0s0.2s
#                    all        565        657      0.904      0.705      0.779       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      3.89G     0.7889     0.5002      1.061         10        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:30<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.7it/s 1.9s0.2s
#                    all        565        657      0.904      0.705      0.779      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      3.91G     0.7751     0.4873      1.055         10        640: 100% ━━━━━━━━━━━━ 642/642 3.0it/s 3:31<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.6it/s 2.0s0.2s
#                    all        565        657      0.906      0.705       0.78       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      3.93G      0.783     0.4998      1.059         12        640: 100% ━━━━━━━━━━━━ 642/642 3.0it/s 3:31<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.5it/s 2.0s0.2s
#                    all        565        657      0.906      0.705       0.78      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      3.94G     0.7805     0.4918       1.06         11        640: 100% ━━━━━━━━━━━━ 642/642 3.0it/s 3:31<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.5it/s 2.0s0.2s
#                    all        565        657      0.906      0.705       0.78       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      3.96G     0.7677     0.4846      1.048         17        640: 100% ━━━━━━━━━━━━ 642/642 3.0it/s 3:31<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.2it/s 2.1s0.3s
#                    all        565        657      0.902      0.704       0.78      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      3.98G     0.7709     0.4891      1.053         10        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:30<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.5it/s 2.0s0.2s
#                    all        565        657      0.898      0.704      0.779      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      3.99G     0.7635     0.4778       1.05          9        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:30<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.6it/s 2.0s0.2s
#                    all        565        657      0.896      0.704      0.779      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      4.01G     0.7556     0.4739      1.048         11        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:30<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.6it/s 2.0s0.2s
#                    all        565        657      0.895      0.704       0.78      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      4.03G     0.7584     0.4721      1.045         13        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:30<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.4it/s 2.0s0.2s
#                    all        565        657      0.892      0.705      0.779      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      4.05G     0.7507     0.4649      1.041         17        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:30<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.4it/s 2.0s0.2s
#                    all        565        657      0.892      0.706      0.779      0.552
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      4.06G     0.7218     0.3786      1.011          4        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:26<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.4it/s 2.0s0.3s
#                    all        565        657       0.89      0.705      0.779      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      4.08G     0.7097     0.3674      1.006          4        640: 100% ━━━━━━━━━━━━ 642/642 3.1it/s 3:24<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.5it/s 2.0s0.3s
#                    all        565        657      0.878      0.726       0.78      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100       4.1G     0.7021     0.3671          1          4        640: 100% ━━━━━━━━━━━━ 642/642 3.2it/s 3:23<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.7it/s 1.9s0.2s
#                    all        565        657      0.878      0.723      0.778      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      4.11G     0.7011     0.3618     0.9983          5        640: 100% ━━━━━━━━━━━━ 642/642 3.2it/s 3:23<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.4it/s 2.0s0.2s
#                    all        565        657      0.878      0.723      0.778      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      4.13G     0.6866     0.3586     0.9926          3        640: 100% ━━━━━━━━━━━━ 642/642 3.2it/s 3:23<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.5it/s 2.0s0.2s
#                    all        565        657      0.877      0.724      0.778      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      4.14G     0.6817     0.3464      0.989          4        640: 100% ━━━━━━━━━━━━ 642/642 3.2it/s 3:23<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.6it/s 2.0s0.2s
#                    all        565        657      0.876      0.724      0.777      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      4.16G      0.676     0.3469     0.9845          4        640: 100% ━━━━━━━━━━━━ 642/642 3.2it/s 3:23<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.5it/s 2.0s0.3s
#                    all        565        657      0.877      0.724      0.777       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      4.18G     0.6685     0.3391     0.9832          4        640: 100% ━━━━━━━━━━━━ 642/642 3.2it/s 3:23<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.4it/s 2.0s0.3s
#                    all        565        657      0.878      0.724      0.777      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100       4.2G     0.6611     0.3382     0.9783          4        640: 100% ━━━━━━━━━━━━ 642/642 3.2it/s 3:24<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.3it/s 2.1s0.2s
#                    all        565        657      0.928      0.689      0.777      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      4.22G     0.6626     0.3321     0.9819          4        640: 100% ━━━━━━━━━━━━ 642/642 3.2it/s 3:24<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.5it/s 2.0s0.3s
#                    all        565        657      0.934      0.689      0.778      0.551
#
# 100 epochs completed in 5.834 hours.
# Optimizer stripped from /kaggle/working/runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from /kaggle/working/runs/detect/train/weights/best.pt, 6.2MB
#
# Validating /kaggle/working/runs/detect/train/weights/best.pt...
# Model summary (fused): 73 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 2.8it/s 3.2s0.2s
#                    all        565        657      0.893      0.705       0.78      0.552
#              ambulance        379        426      0.899      0.826      0.869      0.607
#             fire-truck         22         45      0.854      0.533      0.621      0.472
#                 police        164        186      0.927      0.755      0.849      0.577
# Speed: 0.1ms preprocess, 1.0ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to /kaggle/working/runs/detect/train

# %%
from IPython.display import Image

# %%
Image("/kaggle/working/runs/detect/train/confusion_matrix.png", width=600)

# %%
Image("/kaggle/working/runs/detect/train/confusion_matrix_normalized.png", width=600)

# %%
Image("/kaggle/working/runs/detect/train/results.png", width=600)

# %%
from ultralytics import YOLO
import glob
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import numpy as np
from IPython.display import display
import yaml
from PIL import Image
import shutil

# Function to draw bounding boxes from label file
def draw_ground_truth(img_path, label_path, class_names):
    image = cv2.imread(img_path)
    if image is None:
        # Try with PIL if cv2 fails
        pil_img = Image.open(img_path).convert('RGB')
        image = cv2.cvtColor(np.array(pil_img), cv2.COLOR_RGB2BGR)
    
    h, w, _ = image.shape
    
    if not os.path.exists(label_path):
        return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Return original if no label
    
    with open(label_path, 'r') as f:
        for line in f.readlines():
            parts = line.strip().split()
            if len(parts) < 5:
                continue
            
            cls, x_center, y_center, box_w, box_h = map(float, parts)
            
            # Convert normalized coordinates to pixel values
            x1 = int((x_center - box_w / 2) * w)
            y1 = int((y_center - box_h / 2) * h)
            x2 = int((x_center + box_w / 2) * w)
            y2 = int((y_center + box_h / 2) * h)
            
            # Draw rectangle and class name
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
            class_name = class_names[int(cls)]
            cv2.putText(image, class_name, (x1, y1 - 5), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
    
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Function to load class names from data.yaml
def load_class_names(yaml_path):
    """Load class names from data.yaml file"""
    try:
        with open(yaml_path, 'r') as f:
            data = yaml.safe_load(f)
        class_names = data.get('names', [])
        print(f"✅ Loaded {len(class_names)} classes: {class_names}")
        return class_names
    except Exception as e:
        print(f"❌ Error loading yaml file: {e}")
        return []

# IMPROVED: Convert and VALIDATE images
def create_compatible_images(source_dir, output_dir):
    """Convert all images using OpenCV for better YOLO compatibility"""
    os.makedirs(output_dir, exist_ok=True)
    converted = []
    failed = []
    
    print(f"Converting images from {source_dir}...")
    image_files = [f for f in os.listdir(source_dir) 
                   if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff'))]
    
    for idx, img_file in enumerate(image_files):
        source_path = os.path.join(source_dir, img_file)
        output_path = os.path.join(output_dir, img_file.rsplit('.', 1)[0] + '.jpg')
        
        try:
            # Method 1: Try OpenCV first (most compatible with YOLO)
            img = cv2.imread(source_path)
            
            if img is None:
                # Method 2: Fallback to PIL if OpenCV fails
                pil_img = Image.open(source_path).convert('RGB')
                img = cv2.cvtColor(np.array(pil_img), cv2.COLOR_RGB2BGR)
            
            # Ensure image is valid
            if img is None or img.size == 0:
                raise ValueError("Image is empty or invalid")
            
            # Save with OpenCV (most compatible with YOLO/OpenCV)
            success = cv2.imwrite(output_path, img, [cv2.IMWRITE_JPEG_QUALITY, 95])
            
            if not success:
                raise ValueError("cv2.imwrite failed")
            
            # CRITICAL: Validate the saved image can be read back
            test_img = cv2.imread(output_path)
            if test_img is None:
                raise ValueError("Saved image cannot be read back")
            
            converted.append(output_path)
            
            if (idx + 1) % 100 == 0:
                print(f"  ✓ Converted & validated {idx + 1}/{len(image_files)} images...")
                
        except Exception as e:
            failed.append((img_file, str(e)[:100]))
            if len(failed) <= 5:  # Show first 5 errors
                print(f"  ❌ Failed: {img_file} - {str(e)[:80]}")
    
    print(f"\n✅ Successfully converted: {len(converted)}/{len(image_files)} images")
    if failed:
        print(f"❌ Failed to convert: {len(failed)} images")
        if len(failed) > 5:
            print(f"   (showing first 5, {len(failed)-5} more failed)")
    
    return converted, failed

# Load class names from data.yaml
yaml_path = "/kaggle/working/PCB-2/data.yaml"
class_names = load_class_names(yaml_path)

# Create a temporary directory for converted images
temp_image_dir = "/kaggle/working/temp_valid_images"
source_image_dir = "/kaggle/working/Indian-emergency-vehicles-1/valid/images"

print("\n" + "="*60)
print("STEP 1: Converting images to compatible format")
print("="*60)

# Convert images to ensure compatibility
converted_images, failed_conversions = create_compatible_images(source_image_dir, temp_image_dir)

if not converted_images:
    print("❌ No images could be converted. Please check the source directory.")
    print(f"Source directory exists: {os.path.exists(source_image_dir)}")
    print(f"Files in source: {len(os.listdir(source_image_dir)) if os.path.exists(source_image_dir) else 0}")
    exit()

# Quick validation: test if YOLO can read a sample image
print("\n" + "="*60)
print("VALIDATION: Testing if YOLO can read converted images")
print("="*60)

test_img_path = converted_images[0]
try:
    test_read = cv2.imread(test_img_path)
    if test_read is not None:
        print(f"✅ OpenCV can read converted images (tested: {os.path.basename(test_img_path)})")
        print(f"   Image shape: {test_read.shape}")
    else:
        print(f"❌ WARNING: OpenCV cannot read converted image: {test_img_path}")
except Exception as e:
    print(f"❌ ERROR during validation: {e}")

# Load YOLO model
print("\n" + "="*60)
print("STEP 2: Loading YOLO model")
print("="*60)
model = YOLO("/kaggle/working/runs/detect/train/weights/best.pt")

# Run predictions on converted images
print("\n" + "="*60)
print("STEP 3: Running predictions")
print("="*60)
print(f"Predicting on {len(converted_images)} images...\n")

try:
    # Try batch prediction first
    results = model.predict(source=temp_image_dir, conf=0.25, save=True, project='/kaggle/working/runs/detect', name='predict', exist_ok=True)
    print(f"✅ Batch prediction successful! Processed {len(results)} images")
    successful_count = len(results)
except Exception as e:
    print(f"⚠️ Batch prediction failed: {str(e)[:200]}")
    print("\nTrying individual predictions with error tracking...\n")
    
    # Fallback to individual predictions with better error handling
    results = []
    successful_count = 0
    sample_errors = []
    
    for idx, img_path in enumerate(converted_images[:10]):  # Test first 10
        try:
            # Verify image before prediction
            test_img = cv2.imread(img_path)
            if test_img is None:
                raise ValueError(f"Cannot read image with cv2: {img_path}")
            
            result = model.predict(source=img_path, conf=0.25, save=True, verbose=False)
            results.extend(result)
            successful_count += 1
            
        except Exception as img_error:
            error_msg = str(img_error)[:100]
            sample_errors.append((os.path.basename(img_path), error_msg))
            if len(sample_errors) <= 3:
                print(f"  ❌ Failed: {os.path.basename(img_path)}")
                print(f"     Error: {error_msg}")
    
    print(f"\n✅ Successfully predicted: {successful_count}/10 test images")
    
    if successful_count == 0:
        print("\n❌ CRITICAL: No predictions succeeded. Diagnostic info:")
        print(f"   - Converted images exist: {len(converted_images)}")
        print(f"   - Sample converted path: {converted_images[0]}")
        print(f"   - File exists: {os.path.exists(converted_images[0])}")
        print(f"   - File size: {os.path.getsize(converted_images[0])} bytes")
        print(f"\nSample errors:")
        for fname, err in sample_errors[:3]:
            print(f"   {fname}: {err}")
        exit()

if successful_count == 0:
    print("❌ No successful predictions. Cannot continue.")
    exit()

# Get prediction folder
print("\n" + "="*60)
print("STEP 4: Displaying results")
print("="*60)

predict_folders = glob.glob('/kaggle/working/runs/detect/predict*/')
if not predict_folders:
    print("❌ No prediction folders found!")
    exit()

latest_folder = max(predict_folders, key=os.path.getmtime)
predicted_imgs = sorted(glob.glob(f'{latest_folder}/*.jpg'))
print(f"Found {len(predicted_imgs)} prediction images in {latest_folder}\n")

# Paths
label_dir = '/kaggle/working/Indian-emergency-vehicles-1/valid/labels'

# Create mappings
pred_img_dict = {os.path.basename(p): p for p in predicted_imgs}
temp_to_original = {os.path.basename(f): f.replace(temp_image_dir, source_image_dir) 
                    for f in converted_images}

# Display first 10 images
print("Displaying first 10 comparisons...\n")
display_count = 0

for pred_filename in sorted(pred_img_dict.keys()):
    if display_count >= 10:
        break
    
    # Get paths
    pred_path = pred_img_dict[pred_filename]
    orig_filename = pred_filename.rsplit('.', 1)[0] + '.jpg'  # Handle extension changes
    orig_path = temp_to_original.get(pred_filename, os.path.join(source_image_dir, orig_filename))
    label_path = os.path.join(label_dir, pred_filename.rsplit('.', 1)[0] + '.txt')
    
    try:
        # Load and annotate ground truth
        orig_annotated = draw_ground_truth(orig_path, label_path, class_names)
        
        # Load prediction image
        pred_img = mpimg.imread(pred_path)
        
        # Plot
        fig, axes = plt.subplots(1, 2, figsize=(14, 7))
        
        axes[0].imshow(orig_annotated)
        axes[0].set_title(f"Ground Truth\n{pred_filename}", fontsize=9)
        axes[0].axis('off')
        
        axes[1].imshow(pred_img)
        axes[1].set_title(f"Model Prediction\n{pred_filename}", fontsize=9)
        axes[1].axis('off')
        
        plt.tight_layout()
        plt.show()
        
        display_count += 1
        print(f"✅ Displayed {display_count}/10")
        
    except Exception as e:
        print(f"❌ Error displaying {pred_filename}: {str(e)[:80]}")
        continue

print("\n" + "="*60)
print("COMPLETE!")
print("="*60)
print(f"✅ Displayed {display_count} image comparisons")
print(f"📁 All predictions saved to: {latest_folder}")
print(f"🗑️ Temporary images in: {temp_image_dir}")
print(f"\n💡 TIP: If successful, run predictions on all images:")
print(f"   results = model.predict(source='{temp_image_dir}', conf=0.25, save=True)")
# Out:
# ❌ Error loading yaml file: [Errno 2] No such file or directory: '/kaggle/working/PCB-2/data.yaml'
#
# ============================================================
# STEP 1: Converting images to compatible format
# ============================================================
# Converting images from /kaggle/working/Indian-emergency-vehicles-1/valid/images...
#   ✓ Converted & validated 100/565 images...
#   ✓ Converted & validated 200/565 images...
#   ✓ Converted & validated 300/565 images...
#   ✓ Converted & validated 400/565 images...
#   ✓ Converted & validated 500/565 images...
#
# ✅ Successfully converted: 565/565 images
#
# ============================================================
# VALIDATION: Testing if YOLO can read converted images
# ============================================================
# ✅ OpenCV can read converted images (tested: data19-64-_jpg.rf.e098e9415817c52ffaf1f7546b7c20f8.jpg)
#    Image shape: (850, 478, 3)
#
# ============================================================
# STEP 2: Loading YOLO model
# ============================================================
#
# ============================================================
# STEP 3: Running predictions
# ============================================================
# Predicting on 565 images...
#
#
# image 1/565 /kaggle/working/temp_valid_images/000002_jpg.rf.5cc6df191947db63525952fb51904334.jpg: 640x640 2 ambulances, 7.5ms
# image 2/565 /kaggle/working/temp_valid_images/000036_jpg.rf.b4ac24e07ea59a5fc395867cffc2ed28.jpg: 640x640 1 ambulance, 7.3ms
# image 3/565 /kaggle/working/temp_valid_images/003903_18_jpg.rf.49b48aeeff088a0cc7fcf67f33091899.jpg: 640x640 (no detections), 7.2ms
# image 4/565 /kaggle/working/temp_valid_images/04500361-4b8d-4162-84c5-d0895b095a89_jpg.rf.829e704ada7b5021fbbe4627d31e19f9.jpg: 448x640 1 ambulance, 42.6ms
# image 5/565 /kaggle/working/temp_valid_images/0_0_0_http___cdni-autocarindia-com_Features_DSC_6013_jpg.rf.62d31decb868f3af5496416eaa158d47.jpg: 448x640 2 fire-trucks, 6.2ms
# image 6/565 /kaggle/working/temp_valid_images/101_jpg.rf.de1b1e776f882767d568c867f030a627.jpg: 640x384 1 police, 39.5ms
# image 7/565 /kaggle/working/temp_valid_images/102_jpg.rf.d7a72386ad8e4b84b2fe9500a90598c8.jpg: 640x384 1 police, 5.9ms
# image 8/565 /kaggle/working/temp_valid_images/1036_jpg.rf.aa95d50b36f97e7165412844f1baf919.jpg: 640x640 2 ambulances, 8.0ms
# image 9/565 /kaggle/working/temp_valid_images/106Ambulance_jpg.rf.61d85e3e41b484afe9cea0060c5a2a16.jpg: 640x640 1 ambulance, 7.2ms
# image 10/565 /kaggle/working/temp_valid_images/10_mp4-0000_jpg.rf.41110916c55ab6e62c0ea1626c8d1052.jpg: 384x640 4 ambulances, 1 police, 37.2ms
# image 11/565 /kaggle/working/temp_valid_images/110Ambulance_jpg.rf.e447182d139e208394ecfa1cd37074c7.jpg: 640x640 1 ambulance, 8.8ms
# image 12/565 /kaggle/working/temp_valid_images/117_jpg.rf.a14650bbfd2d0f6338959b1ac28b0210.jpg: 640x384 1 police, 6.3ms
# image 13/565 /kaggle/working/temp_valid_images/119_jpg.rf.23fcfffca243e4155ef28eb20afdecb4.jpg: 640x384 1 police, 5.7ms
# image 14/565 /kaggle/working/temp_valid_images/120Ambulance_jpg.rf.a3595ed59305965498c7e7126d3a3f89.jpg: 640x640 2 ambulances, 7.9ms
# image 15/565 /kaggle/working/temp_valid_images/121_jpg.rf.cd6cc3e0150e541f3554396313f688d4.jpg: 640x384 1 police, 6.4ms
# image 16/565 /kaggle/working/temp_valid_images/121de9bd-0be5-4050-9117-cbc7ebf0a16d_jpg.rf.078dfb91b521a618e15f15da7ecaab10.jpg: 480x640 1 ambulance, 39.7ms
# image 17/565 /kaggle/working/temp_valid_images/122_jpg.rf.19f4adcd0dd4880bb651869dcaec7382.jpg: 640x384 1 police, 6.4ms
# image 18/565 /kaggle/working/temp_valid_images/123_jpg.rf.0d6b79197d236724e1dcca0fb686db50.jpg: 640x384 1 police, 5.6ms
# image 19/565 /kaggle/working/temp_valid_images/124_jpg.rf.0ac867e44b123d01a1cc68e793088e35.jpg: 640x384 1 police, 5.6ms
# image 20/565 /kaggle/working/temp_valid_images/127_jpg.rf.a704a811fdf133a4c5a246d09969e5bb.jpg: 640x384 1 police, 5.6ms
# image 21/565 /kaggle/working/temp_valid_images/132_jpg.rf.b3fb6a22db8bc39e154618d0040b0c35.jpg: 640x384 1 police, 5.6ms
# image 22/565 /kaggle/working/temp_valid_images/13_mp4-0000_jpg.rf.47ac7d43e2a306cd553614dbf11ced7e.jpg: 384x640 2 polices, 6.4ms
# image 23/565 /kaggle/working/temp_valid_images/13_mp4-0001_jpg.rf.94cd578022b708076755dfa8510bd7f4.jpg: 384x640 2 polices, 5.7ms
# image 24/565 /kaggle/working/temp_valid_images/141_jpg.rf.08b7a488a54dec39797bdb922bd80fd0.jpg: 640x384 2 polices, 6.4ms
# image 25/565 /kaggle/working/temp_valid_images/143_jpg.rf.d6b7eea9bd40f70e6f4736eca0324f7f.jpg: 640x384 1 police, 5.8ms
# image 26/565 /kaggle/working/temp_valid_images/146_jpg.rf.d4f4aef94fa678a259e2b0a2e2649969.jpg: 640x384 1 police, 5.6ms
# image 27/565 /kaggle/working/temp_valid_images/14Ambulance_jpg.rf.510c6a38bef7069192462353cd35ff17.jpg: 640x640 1 ambulance, 7.9ms
# image 28/565 /kaggle/working/temp_valid_images/14_mp4-0000_jpg.rf.2540f21f57c5243f16535ba205d6fed0.jpg: 384x640 2 ambulances, 6.3ms
# image 29/565 /kaggle/working/temp_valid_images/150_jpg.rf.52c3f293ebedec4220b375109383519c.jpg: 640x384 1 police, 6.3ms
# image 30/565 /kaggle/working/temp_valid_images/152_jpg.rf.a221f6fc2337aaae85999479af3166f8.jpg: 640x384 1 police, 5.8ms
# image 31/565 /kaggle/working/temp_valid_images/153_jpg.rf.baae116672167c254eaf1658351d8c48.jpg: 640x384 1 police, 5.7ms
# image 32/565 /kaggle/working/temp_valid_images/16dd00bc-07e6-4a5b-85de-1aa1871f0104_jpg.rf.48ac93e891afe342102c4da50a913536.jpg: 512x640 1 fire-truck, 38.2ms
# image 33/565 /kaggle/working/temp_valid_images/172_jpg.rf.4f659618dcec5ffe6371b076f2e28f0c.jpg: 640x384 1 police, 6.4ms
# image 34/565 /kaggle/working/temp_valid_images/174_jpg.rf.a1389dd0d32b9c5b59239bf000036ee5.jpg: 640x384 1 police, 5.6ms
# image 35/565 /kaggle/working/temp_valid_images/185_jpg.rf.0198123d658963e332f5f03e8e77504d.jpg: 640x384 1 police, 5.5ms
# image 36/565 /kaggle/working/temp_valid_images/186_jpg.rf.9e17abf861e4b0f03f3886243fa589a5.jpg: 640x384 1 police, 5.7ms
# image 37/565 /kaggle/working/temp_valid_images/188_jpg.rf.70432fab92964a61c989bc8b2b7e4f83.jpg: 640x384 1 police, 5.5ms
# image 38/565 /kaggle/working/temp_valid_images/192_jpg.rf.68e7b5cee6d9f35490cfa67a9966b728.jpg: 640x384 1 police, 7.0ms
# image 39/565 /kaggle/working/temp_valid_images/195_jpg.rf.6c3d93714399b04a47515f5fad0306f6.jpg: 640x384 1 police, 6.6ms
# image 40/565 /kaggle/working/temp_valid_images/1_mp4-0003_jpg.rf.10e0c1fdef4f81b26a2ded3028dfcfd9.jpg: 384x640 1 ambulance, 6.2ms
# image 41/565 /kaggle/working/temp_valid_images/2557b387-1f2f-407d-b7c6-2e288182df56_jpg.rf.2d9116a5dbad0e1d86abb6044c4bf5a4.jpg: 448x640 1 fire-truck, 6.6ms
# image 42/565 /kaggle/working/temp_valid_images/2Ambulance_jpg.rf.4bb5067546fe13fa798a95f3fb00196e.jpg: 640x640 1 ambulance, 7.8ms
# image 43/565 /kaggle/working/temp_valid_images/2_mp4-0004_jpg.rf.9b5d71ee3fe553cfd7fcd3af82591478.jpg: 384x640 1 police, 7.1ms
# image 44/565 /kaggle/working/temp_valid_images/2c35abdc-af26-41fa-bf08-09053999383b_jpg.rf.bcec14712f93485cf6dc29705b4d124e.jpg: 448x640 2 ambulances, 6.4ms
# image 45/565 /kaggle/working/temp_valid_images/310b13b5-0a9f-4de8-836d-014cc3143d5c_jpg.rf.17dff08c3a04d5698041cb897be7b981.jpg: 480x640 1 ambulance, 6.4ms
# image 46/565 /kaggle/working/temp_valid_images/31Ambulance_jpg.rf.293a7e6c84a292a8414bf67993f462ff.jpg: 640x640 (no detections), 7.8ms
# image 47/565 /kaggle/working/temp_valid_images/33Ambulance_jpg.rf.d1b2e5f7b82b448cbfb067cc41e6edf2.jpg: 640x640 1 ambulance, 7.1ms
# image 48/565 /kaggle/working/temp_valid_images/35Ambulance_jpg.rf.d73f8c998a2abab85c8de91ddefe732e.jpg: 640x640 1 ambulance, 7.1ms
# image 49/565 /kaggle/working/temp_valid_images/35_jpg.rf.c1c99b185a2216a2f276c7c7b6098e92.jpg: 640x384 1 police, 6.8ms
# image 50/565 /kaggle/working/temp_valid_images/374e6583-aa06-4141-9709-4ef9ec421087_jpg.rf.867ee0a4f005aca4b542737bcdd19391.jpg: 320x640 (no detections), 38.5ms
# image 51/565 /kaggle/working/temp_valid_images/37Ambulance_jpg.rf.baaf529982e798d591f7d3bdebaed079.jpg: 640x640 1 ambulance, 7.7ms
# image 52/565 /kaggle/working/temp_valid_images/38100b8e-53f5-4ef6-8810-5abb8f461035_jpg.rf.09b05ce78dcab9dabeb81663ddea420a.jpg: 480x640 2 fire-trucks, 6.4ms
# image 53/565 /kaggle/working/temp_valid_images/38b45be8-33c1-433c-aa6d-cafd26ce94ca_png.rf.1ac8cbca0c4b2820c3b8c36c54da0dc3.jpg: 480x640 2 ambulances, 5.7ms
# image 54/565 /kaggle/working/temp_valid_images/39_jpg.rf.fa22b5b784b0bd0182133a60ce02b3aa.jpg: 640x384 1 police, 6.3ms
# image 55/565 /kaggle/working/temp_valid_images/3_mp4-0003_jpg.rf.93da0b9a5634639899b4cde1425766e7.jpg: 384x640 1 police, 6.6ms
# image 56/565 /kaggle/working/temp_valid_images/3_mp4-0006_jpg.rf.847f4c468bcd44363398990731095b7b.jpg: 384x640 1 police, 5.7ms
# image 57/565 /kaggle/working/temp_valid_images/40_jpg.rf.1d4a44294d259ccfb330939ce6f97b1a.jpg: 640x384 1 police, 6.2ms
# image 58/565 /kaggle/working/temp_valid_images/42_jpg.rf.7a3555180ded9a22517904512bdb8b6c.jpg: 640x384 1 police, 5.6ms
# image 59/565 /kaggle/working/temp_valid_images/47_jpg.rf.1cdae0033e6ddd37ace4e9ce6759c8a1.jpg: 640x384 1 police, 5.4ms
# image 60/565 /kaggle/working/temp_valid_images/49Ambulance_jpg.rf.92ff89dd7918a1f25fc0db8dc20935a5.jpg: 640x640 (no detections), 7.7ms
# image 61/565 /kaggle/working/temp_valid_images/49_jpg.rf.a1c3a8a89bec0554a125df2e19010a4e.jpg: 640x384 1 police, 6.2ms
# image 62/565 /kaggle/working/temp_valid_images/4_mp4-0002_jpg.rf.6f3166d277ea8390024e1bf0a9ee368e.jpg: 384x640 1 police, 6.3ms
# image 63/565 /kaggle/working/temp_valid_images/4_mp4-0003_jpg.rf.a519a1ad770b491d86a2fc7983bb4e6e.jpg: 384x640 1 police, 5.6ms
# image 64/565 /kaggle/working/temp_valid_images/50_jpg.rf.360ee45a82b8ab37c0ec138b04afb98f.jpg: 640x384 1 police, 6.4ms
# image 65/565 /kaggle/working/temp_valid_images/53d9d42b-734b-4089-b83b-6213820429e5_jpg.rf.81431f7d372d6d57415f8da0d17cb7d7.jpg: 416x640 2 ambulances, 38.9ms
# image 66/565 /kaggle/working/temp_valid_images/5_mp4-0000_jpg.rf.4c16979dd476a399236bfbe8cd1a9453.jpg: 384x640 1 police, 6.4ms
# image 67/565 /kaggle/working/temp_valid_images/5_mp4-0003_jpg.rf.c10d8a178ed39c51ecc2b09dfce8d49e.jpg: 384x640 1 police, 5.9ms
# image 68/565 /kaggle/working/temp_valid_images/6f79f6eb-cb8d-4792-a2f0-2b9b5083a57a_jpg.rf.3fdc1eabb21c900539f840e4d5cbf759.jpg: 352x640 1 fire-truck, 38.9ms
# image 69/565 /kaggle/working/temp_valid_images/70a3e615-fe76-47bd-be34-4ac7206bea06_jpg.rf.50a33307cb34f4287f4f83525a0a7b8b.jpg: 448x640 1 fire-truck, 6.6ms
# image 70/565 /kaggle/working/temp_valid_images/7464d7b8-7eee-4d75-a07b-b0020d40a299_jpg.rf.3defc5d2844c055f31d1aaf9b8fa909c.jpg: 384x640 2 ambulances, 6.7ms
# image 71/565 /kaggle/working/temp_valid_images/7_mp4-0003_jpg.rf.be1ef47cebae4b9f5202b796816748e2.jpg: 384x640 1 police, 6.4ms
# image 72/565 /kaggle/working/temp_valid_images/7f88ab54-fbb7-4fa2-8e48-4edaf3f4c850_jpg.rf.eeb41be538e1583d7bfa3168c5c6991d.jpg: 480x640 1 fire-truck, 6.4ms
# image 73/565 /kaggle/working/temp_valid_images/7f9d78a0-1733-442d-8446-be1908bea1a7_jpg.rf.cbbf794c192cd7c85caf87ebc3faf7d0.jpg: 448x640 1 fire-truck, 6.5ms
# image 74/565 /kaggle/working/temp_valid_images/81_jpg.rf.9fb5c594bde7dd868c9209afa63da043.jpg: 640x384 1 police, 6.8ms
# image 75/565 /kaggle/working/temp_valid_images/83_jpg.rf.f558fefca059f8664af313dbc52d27c8.jpg: 640x384 1 police, 5.9ms
# image 76/565 /kaggle/working/temp_valid_images/84_jpg.rf.d58efc157bf2dbe180f27915a26450da.jpg: 640x384 1 police, 5.8ms
# image 77/565 /kaggle/working/temp_valid_images/85_jpg.rf.a4c28ef0c6b9d539b7de500e7433c43f.jpg: 640x384 1 police, 5.8ms
# image 78/565 /kaggle/working/temp_valid_images/8e8e3eac-a0ad-46a6-b125-5f76a2d35cd8_jpg.rf.9d8e782b81ea2162b74998581561f7d9.jpg: 448x640 (no detections), 6.4ms
# image 79/565 /kaggle/working/temp_valid_images/92_jpg.rf.c7bfa38fd997df1ec3d57a2d9160e0f9.jpg: 640x384 1 police, 6.3ms
# image 80/565 /kaggle/working/temp_valid_images/95_jpg.rf.0f26e918b432656b2a9195f063520fd8.jpg: 640x384 1 police, 6.1ms
# image 81/565 /kaggle/working/temp_valid_images/981dc3d2-df0f-4d67-a544-f5a6cddc1690_png.rf.3a6a0ce7efc98c35c25eda58987a9d94.jpg: 416x640 2 ambulances, 6.4ms
# image 82/565 /kaggle/working/temp_valid_images/98_jpg.rf.73584590ab05f8e8f01dd7fbb126a7cb.jpg: 640x384 1 police, 6.5ms
# image 83/565 /kaggle/working/temp_valid_images/98b0f7ad-1226-413b-a7c1-f3dadf5f4896_jpg.rf.73fd46b1b278e799d1de734634ff240b.jpg: 448x640 1 fire-truck, 6.4ms
# image 84/565 /kaggle/working/temp_valid_images/9_mp4-0006_jpg.rf.126a0f1d13505f558951ed8d97476174.jpg: 384x640 1 ambulance, 6.6ms
# image 85/565 /kaggle/working/temp_valid_images/9a37e927-fa25-45e5-93a6-8eecf0da46d0_jpg.rf.f122c62f3635744f39fd99e2ccf2e08a.jpg: 384x640 (no detections), 5.9ms
# image 86/565 /kaggle/working/temp_valid_images/Ambulances-108-india_102_jpeg_jpg.rf.6dfe6976a4aa268e4d23b32456ef5128.jpg: 640x640 2 ambulances, 7.8ms
# image 87/565 /kaggle/working/temp_valid_images/Keralapolice_webp.rf.23469d60a8b6ab63634b970ac71faaa1.jpg: 480x640 2 ambulances, 1 police, 6.4ms
# image 88/565 /kaggle/working/temp_valid_images/Maruti-Suzuki-Ertiga-all-Women-Police-Vehicle_jpg.rf.032e0e7bc367c7002f6306284be973e4.jpg: 448x640 2 polices, 6.4ms
# image 89/565 /kaggle/working/temp_valid_images/MumbaiPoliceGetsNewErtiga_jpg.rf.a446e6200c2f59e77e54ee5436891445.jpg: 448x640 2 ambulances, 5.6ms
# image 90/565 /kaggle/working/temp_valid_images/Screenshot-2024-12-30-144401_png.rf.b2d17267c9c9e59c7ced2c3e9635271d.jpg: 288x640 1 ambulance, 2 fire-trucks, 39.7ms
# image 91/565 /kaggle/working/temp_valid_images/Screenshot-2024-12-30-144420_png.rf.5e4088a533dd965bd2d34e8f82bcc243.jpg: 288x640 2 fire-trucks, 5.9ms
# image 92/565 /kaggle/working/temp_valid_images/Screenshot-2024-12-30-144437_png.rf.3492b420a8577cd626626d68a5ec2f27.jpg: 320x640 1 fire-truck, 1 police, 6.7ms
# image 93/565 /kaggle/working/temp_valid_images/Screenshot-2024-12-30-144702_png.rf.03e915699f3e8ad2387763ff6d648491.jpg: 320x640 6 polices, 6.1ms
# image 94/565 /kaggle/working/temp_valid_images/TNIE_import_2023_7_26_original_Kerala_Highway_Police_Toyota_Innova_avif.rf.83873ebef07b01d0bc5c8eba16123583.jpg: 480x640 (no detections), 6.4ms
# image 95/565 /kaggle/working/temp_valid_images/ab05f7a7-c74d-4629-af52-cd039e591437_jpg.rf.300f7bc0268db95cbcc80438d2696358.jpg: 448x640 2 fire-trucks, 6.7ms
# image 96/565 /kaggle/working/temp_valid_images/af27b2ed-bfd4-4b01-88ba-22cfe5e14e1d_JPG.rf.a4640beb4dd124c1a9527e18fb428b07.jpg: 448x640 1 fire-truck, 5.7ms
# image 97/565 /kaggle/working/temp_valid_images/ambulance2-114-_jpg.rf.3116394fb0b9981b3d6d6828d106f637.jpg: 640x640 2 ambulances, 7.8ms
# image 98/565 /kaggle/working/temp_valid_images/ambulance2-141-_jpg.rf.68e2767ce8d238047bde4d32f6e77438.jpg: 640x640 1 ambulance, 7.1ms
# image 99/565 /kaggle/working/temp_valid_images/ambulance2-158-_jpg.rf.49b45ca61148fa871f1bd456165f1921.jpg: 640x640 1 ambulance, 7.1ms
# image 100/565 /kaggle/working/temp_valid_images/ambulance2-168-_jpg.rf.2158eac459ac7479b2a4ca901a32fa4d.jpg: 640x640 1 ambulance, 7.1ms
# image 101/565 /kaggle/working/temp_valid_images/ambulance2-173-_jpg.rf.a031cec471e44bf5528e7123d305a2e5.jpg: 640x640 (no detections), 7.0ms
# image 102/565 /kaggle/working/temp_valid_images/ambulance2-183-_jpg.rf.ef0cf7e71cbe267caed7f1b43ccf34eb.jpg: 640x640 1 ambulance, 7.1ms
# image 103/565 /kaggle/working/temp_valid_images/ambulance2-188-_jpg.rf.5154059442802e781a4c0ad39ca571a6.jpg: 640x640 1 ambulance, 7.1ms
# image 104/565 /kaggle/working/temp_valid_images/ambulance2-192-_jpg.rf.639af51683e0aa0b0f5dd4a7aa5910c5.jpg: 640x640 2 ambulances, 7.1ms
# image 105/565 /kaggle/working/temp_valid_images/ambulance2-201-_jpg.rf.421ac36421cced5267f037b9209e838d.jpg: 640x640 (no detections), 7.1ms
# image 106/565 /kaggle/working/temp_valid_images/ambulance2-230-_jpg.rf.b43a6e708803f03c8b12ee98e253373e.jpg: 640x640 3 ambulances, 7.1ms
# image 107/565 /kaggle/working/temp_valid_images/ambulance2-254-_jpg.rf.f25377538d79e245b3058e369f6154b7.jpg: 640x640 1 ambulance, 7.0ms
# image 108/565 /kaggle/working/temp_valid_images/ambulance2-324-_jpg.rf.0488dae29c9a995444fa398d06f9e53a.jpg: 640x640 1 ambulance, 7.1ms
# image 109/565 /kaggle/working/temp_valid_images/ambulance2-367-_jpg.rf.f796663cb03c80ef537996eb6880432f.jpg: 640x640 2 ambulances, 7.0ms
# image 110/565 /kaggle/working/temp_valid_images/ambulance2-392-_jpg.rf.74dee0b4ff8c2aeb73f52fd5cbe99f17.jpg: 640x640 (no detections), 7.1ms
# image 111/565 /kaggle/working/temp_valid_images/ambulance2-407-_jpg.rf.394b8f5e5794527035d2d6ab0e1826d3.jpg: 640x640 3 ambulances, 7.1ms
# image 112/565 /kaggle/working/temp_valid_images/ambulance2-410-_jpg.rf.0a4765cbb7b5eeb69503013e36f8af4d.jpg: 640x640 1 ambulance, 7.0ms
# image 113/565 /kaggle/working/temp_valid_images/ambulance2-436-_jpg.rf.d30b1e0a3d5459b293970a55f692168d.jpg: 640x640 3 ambulances, 7.1ms
# image 114/565 /kaggle/working/temp_valid_images/ambulance2-439-_jpg.rf.27fae83ba01ec8f8032dbbcad1532d9c.jpg: 640x640 1 ambulance, 7.1ms
# image 115/565 /kaggle/working/temp_valid_images/ambulance2-447-_jpg.rf.ad312adc0ba70663c600c38fc33cac1b.jpg: 640x640 2 ambulances, 7.1ms
# image 116/565 /kaggle/working/temp_valid_images/ambulance2-45-_jpg.rf.8410a51588c9684ef585901a69dbaf7b.jpg: 640x640 3 ambulances, 7.1ms
# image 117/565 /kaggle/working/temp_valid_images/back_110_jpeg_jpg.rf.bfc769a6f8f1d68ead5feb78faa48d29.jpg: 640x640 1 ambulance, 7.0ms
# image 118/565 /kaggle/working/temp_valid_images/back_132_jpeg_jpg.rf.19bf6c7491a1722ce8eb5fb65a7e73db.jpg: 640x640 1 ambulance, 6.6ms
# image 119/565 /kaggle/working/temp_valid_images/back_132_jpeg_jpg.rf.4d191321cda73c58a2c6f353b7d9decc.jpg: 640x640 1 ambulance, 5.6ms
# image 120/565 /kaggle/working/temp_valid_images/back_134_jpeg_jpg.rf.3bd9aa35698b44ba57db66dad620b7b5.jpg: 640x640 1 ambulance, 5.6ms
# image 121/565 /kaggle/working/temp_valid_images/back_136_jpeg_jpg.rf.450c4d595bdc2666c4da448be643fbc2.jpg: 640x640 1 ambulance, 5.6ms
# image 122/565 /kaggle/working/temp_valid_images/back_139_jpeg_jpg.rf.868f8830e89bea2ba5d1fb78a1908d98.jpg: 640x640 1 ambulance, 5.6ms
# image 123/565 /kaggle/working/temp_valid_images/back_160_jpeg_jpg.rf.76ccefcd6abb67402063bafdcd3440ad.jpg: 640x640 1 ambulance, 5.6ms
# image 124/565 /kaggle/working/temp_valid_images/back_160_jpeg_jpg.rf.f921f16347eb6dfbe331d0c49e405954.jpg: 640x640 1 ambulance, 5.6ms
# image 125/565 /kaggle/working/temp_valid_images/back_178_jpeg_jpg.rf.792dafa7db20d11dc6ed258c4bfd6401.jpg: 640x640 1 ambulance, 5.6ms
# image 126/565 /kaggle/working/temp_valid_images/back_178_jpeg_jpg.rf.ec83ef71dbb78b320320a208e7829c5b.jpg: 640x640 1 ambulance, 5.9ms
# image 127/565 /kaggle/working/temp_valid_images/back_195-9th-copy-_jpeg_jpg.rf.fd7405f5fbe6b77ae14b5f4c2ade6459.jpg: 640x640 1 ambulance, 5.8ms
# image 128/565 /kaggle/working/temp_valid_images/back_1_jpeg_jpg.rf.1edf6e66c4293083eb5c002384559617.jpg: 640x640 1 ambulance, 5.7ms
# image 129/565 /kaggle/working/temp_valid_images/back_1_jpeg_jpg.rf.a15f99e3f5a32ff1c1481e1fc2bb8652.jpg: 640x640 1 ambulance, 5.6ms
# image 130/565 /kaggle/working/temp_valid_images/back_201_jpeg_jpg.rf.becf772dcf9c47f7123bcfb28efa2aaa.jpg: 640x640 1 ambulance, 5.6ms
# image 131/565 /kaggle/working/temp_valid_images/back_27_jpeg_jpg.rf.5906d63c8d8d7c42533a9328c905bd39.jpg: 640x640 1 ambulance, 5.7ms
# image 132/565 /kaggle/working/temp_valid_images/back_29_jpeg_jpg.rf.dde925d6586552c8655f4fc8a480732f.jpg: 640x640 1 ambulance, 5.7ms
# image 133/565 /kaggle/working/temp_valid_images/back_3_jpeg_jpg.rf.cc5fa3cfefbba1fe3455ae32d63c587d.jpg: 640x640 1 ambulance, 5.7ms
# image 134/565 /kaggle/working/temp_valid_images/back_4_jpeg_jpg.rf.3fc4a63a7f1938cccffdca2d6133b043.jpg: 640x640 1 ambulance, 5.5ms
# image 135/565 /kaggle/working/temp_valid_images/back_55_jpeg_jpg.rf.1916614d964292ff07ac3ba164750a77.jpg: 640x640 1 ambulance, 5.5ms
# image 136/565 /kaggle/working/temp_valid_images/back_68_jpeg_jpg.rf.3b31c096a0f50cc29808dc007b300b9c.jpg: 640x640 1 ambulance, 5.4ms
# image 137/565 /kaggle/working/temp_valid_images/back_69_jpeg_jpg.rf.beaf7cd97ee1cf1c9536a3a536bbc419.jpg: 640x640 1 ambulance, 5.8ms
# image 138/565 /kaggle/working/temp_valid_images/back_76_jpeg_jpg.rf.f17ed0b39924a8a3c06c693faa969dea.jpg: 640x640 1 ambulance, 5.5ms
# image 139/565 /kaggle/working/temp_valid_images/back_7_jpeg_jpg.rf.39a211c07be7312616ad3b05a01ad7ab.jpg: 640x640 1 ambulance, 5.6ms
# image 140/565 /kaggle/working/temp_valid_images/back_8_jpeg_jpg.rf.eaf16e492154a9dc4a777d4629351b72.jpg: 640x640 1 ambulance, 5.7ms
# image 141/565 /kaggle/working/temp_valid_images/back_97_jpeg_jpg.rf.15b1c0f4d29e10f538623c45cee22bd2.jpg: 640x640 1 ambulance, 6.0ms
# image 142/565 /kaggle/working/temp_valid_images/back_97_jpeg_jpg.rf.4be762ea718601d70aec2704bd1eb86b.jpg: 640x640 1 ambulance, 5.5ms
# image 143/565 /kaggle/working/temp_valid_images/back_jpeg_jpg.rf.ce060a355cf31282584138195cb67281.jpg: 640x640 1 ambulance, 5.5ms
# image 144/565 /kaggle/working/temp_valid_images/bbcd8734-efd6-44b4-b07d-289c6d3d5f86_jpg.rf.045844ec811f9e0994d6deac2555c38d.jpg: 512x640 2 ambulances, 6.1ms
# image 145/565 /kaggle/working/temp_valid_images/c445e881-1673-47dd-a0a1-49da78d512f3_jpg.rf.e0b51512d3e0aa5f4facff1779ac9bcd.jpg: 448x640 1 fire-truck, 6.1ms
# image 146/565 /kaggle/working/temp_valid_images/c589f008-1cc8-415c-9c12-d4e6226c349b_jpg.rf.855e72a9436fcc187d09a05a50be3acc.jpg: 480x640 1 fire-truck, 6.5ms
# image 147/565 /kaggle/working/temp_valid_images/c5f17345-47a0-43f4-90bd-efafcca20506_jpg.rf.ffa2f33d07aa7c34c39fdc917d7f8033.jpg: 480x640 1 ambulance, 5.7ms
# image 148/565 /kaggle/working/temp_valid_images/cdd0e289-e7b1-46f1-853b-96c3a9ed91bf_jpg.rf.ad7c4ff22afd0469fd3ccd004e559b46.jpg: 448x640 1 fire-truck, 6.6ms
# image 149/565 /kaggle/working/temp_valid_images/data1-101-_jpg.rf.935b5194e0b9ac9c1709f77729329eaa.jpg: 640x384 1 police, 6.3ms
# image 150/565 /kaggle/working/temp_valid_images/data1-22-_jpg.rf.579410ec29f0d6af70f534bcda146edc.jpg: 640x384 1 police, 5.6ms
# image 151/565 /kaggle/working/temp_valid_images/data1-32-_jpg.rf.ed405ba765e15de85a65b032a03b5277.jpg: 640x384 1 police, 5.3ms
# image 152/565 /kaggle/working/temp_valid_images/data1-35-_jpg.rf.9ccdcaac3f8fcb9c89395fe3082c5664.jpg: 640x384 1 police, 5.5ms
# image 153/565 /kaggle/working/temp_valid_images/data1-38-_jpg.rf.577477c0521aaddf218f2b2dc8db2ff9.jpg: 640x384 1 police, 5.6ms
# image 154/565 /kaggle/working/temp_valid_images/data1-44-_jpg.rf.3365c4165433514b96527d5eae93f463.jpg: 640x384 1 police, 5.5ms
# image 155/565 /kaggle/working/temp_valid_images/data1-52-_jpg.rf.e1f6165c1b7de5785f32c6e72b070583.jpg: 640x384 1 police, 5.5ms
# image 156/565 /kaggle/working/temp_valid_images/data1-56-_jpg.rf.4f7f813b79090ad35cae1fba568cf7bc.jpg: 640x384 1 police, 5.7ms
# image 157/565 /kaggle/working/temp_valid_images/data1-57-_jpg.rf.c61af8021d0e28ee2456d0d96aa8ca60.jpg: 640x384 1 police, 5.6ms
# image 158/565 /kaggle/working/temp_valid_images/data1-58-_jpg.rf.83b2d4e3563a78d3250649860fa61e0d.jpg: 640x384 1 police, 5.5ms
# image 159/565 /kaggle/working/temp_valid_images/data1-59-_jpg.rf.8941ddd138864839770247249d3b0926.jpg: 640x384 1 police, 6.1ms
# image 160/565 /kaggle/working/temp_valid_images/data1-60-_jpg.rf.56cdd251b55a62af789ff21862e2d286.jpg: 640x384 1 police, 5.5ms
# image 161/565 /kaggle/working/temp_valid_images/data1-7-_jpg.rf.a817dbc62eac628b1d68bc02c2c8d882.jpg: 640x384 1 police, 8.1ms
# image 162/565 /kaggle/working/temp_valid_images/data1-70-_jpg.rf.d607a073830507d8c13ea67df6447795.jpg: 640x384 1 police, 8.6ms
# image 163/565 /kaggle/working/temp_valid_images/data1-75-_jpg.rf.64cd0e15c317fbc6de7d1bb2aa56af4a.jpg: 640x384 1 police, 9.3ms
# image 164/565 /kaggle/working/temp_valid_images/data1-77-_jpg.rf.e35a960f41dd9192b2ecc0dba6348e88.jpg: 640x384 1 police, 7.4ms
# image 165/565 /kaggle/working/temp_valid_images/data1-81-_jpg.rf.51383ec972d9e34e811334e295142c7c.jpg: 640x384 1 police, 9.0ms
# image 166/565 /kaggle/working/temp_valid_images/data1-89-_jpg.rf.9bfaded42e0e9da1c9a0c3e7d718e498.jpg: 640x384 1 police, 5.5ms
# image 167/565 /kaggle/working/temp_valid_images/data1-90-_jpg.rf.82e3238229dc9099c4bb2dd4977a3ec3.jpg: 640x384 1 police, 5.5ms
# image 168/565 /kaggle/working/temp_valid_images/data1-93-_jpg.rf.44711d8a20ba8374d32b8eb3fa49e030.jpg: 640x384 1 police, 5.7ms
# image 169/565 /kaggle/working/temp_valid_images/data1-98-_jpg.rf.648fb2ecdb6aa0dc657751363a60419a.jpg: 640x384 1 police, 5.4ms
# image 170/565 /kaggle/working/temp_valid_images/data10-14-_jpg.rf.e7665cc94ce0c4a779f90c7a905af00a.jpg: 640x384 1 ambulance, 5.3ms
# image 171/565 /kaggle/working/temp_valid_images/data10-15-_jpg.rf.ce2a1274a9cbfccb9bc89ff93184bc93.jpg: 640x384 1 ambulance, 5.3ms
# image 172/565 /kaggle/working/temp_valid_images/data10-17-_jpg.rf.8df7e83e108a7efa19f04411cb898ecd.jpg: 640x384 1 ambulance, 5.3ms
# image 173/565 /kaggle/working/temp_valid_images/data10-18-_jpg.rf.89d30f881a1fd2a8b8e97f6e8f35c58a.jpg: 640x384 1 ambulance, 5.4ms
# image 174/565 /kaggle/working/temp_valid_images/data10-20-_jpg.rf.4dea8a96afb44396f8b5a89258c73956.jpg: 640x384 1 ambulance, 6.0ms
# image 175/565 /kaggle/working/temp_valid_images/data10-31-_jpg.rf.95edac806c0aff136f087911d3f771b3.jpg: 640x384 1 police, 5.6ms
# image 176/565 /kaggle/working/temp_valid_images/data10-32-_jpg.rf.c6d2ecd162491a2c73a608f9f7c7ec20.jpg: 640x384 1 police, 5.4ms
# image 177/565 /kaggle/working/temp_valid_images/data10-36-_jpg.rf.def7de773ea8ad39527bd10cb3fec4bd.jpg: 640x384 2 polices, 5.3ms
# image 178/565 /kaggle/working/temp_valid_images/data10-58-_jpg.rf.cbea0ea887e131bf59c6c79b42bad00e.jpg: 640x384 1 ambulance, 5.4ms
# image 179/565 /kaggle/working/temp_valid_images/data10-6-_jpg.rf.4822f7cd1b877b87dc16f4576334c4ee.jpg: 640x384 1 ambulance, 1 police, 5.3ms
# image 180/565 /kaggle/working/temp_valid_images/data10-60-_jpg.rf.11ef5dcff813f13055c00b3ec3d30bd2.jpg: 640x384 1 ambulance, 5.4ms
# image 181/565 /kaggle/working/temp_valid_images/data10-62-_jpg.rf.bf3173a25bae1e1abd28a1e78d5fa767.jpg: 640x384 1 police, 5.3ms
# image 182/565 /kaggle/working/temp_valid_images/data10-76-_jpg.rf.c6177d3fd721457f6282164ff0785700.jpg: 640x384 1 ambulance, 5.3ms
# image 183/565 /kaggle/working/temp_valid_images/data10-79-_jpg.rf.e8e74d238c4ca03b4220fc7bd6e2f248.jpg: 640x384 1 ambulance, 5.5ms
# image 184/565 /kaggle/working/temp_valid_images/data10-8-_jpg.rf.3ac8740c85c54f72956684df2fc0a93d.jpg: 640x384 1 ambulance, 5.3ms
# image 185/565 /kaggle/working/temp_valid_images/data10-80-_jpg.rf.a13d7eb377faa5203e7feaad990de44d.jpg: 640x384 1 ambulance, 6.7ms
# image 186/565 /kaggle/working/temp_valid_images/data10-90-_jpg.rf.edb22c200befd765a17a61db1ad38c11.jpg: 640x384 1 ambulance, 5.8ms
# image 187/565 /kaggle/working/temp_valid_images/data10-92-_jpg.rf.dfe8bcdd39d0848d23eb18a595cdf534.jpg: 640x384 1 ambulance, 5.6ms
# image 188/565 /kaggle/working/temp_valid_images/data11-23-_jpg.rf.6810525989c0c5235e967fe812a4c694.jpg: 640x384 1 ambulance, 5.6ms
# image 189/565 /kaggle/working/temp_valid_images/data11-25-_jpg.rf.64f29268b2005eed9c1324823762b5ad.jpg: 640x384 1 ambulance, 5.5ms
# image 190/565 /kaggle/working/temp_valid_images/data11-27-_jpg.rf.0b4f15a56aca01adcf7db37a2c28886b.jpg: 640x384 1 ambulance, 5.5ms
# image 191/565 /kaggle/working/temp_valid_images/data11-35-_jpg.rf.868b14c681262d973867627e8bde07cf.jpg: 640x384 1 ambulance, 5.7ms
# image 192/565 /kaggle/working/temp_valid_images/data11-38-_jpg.rf.4e53a39181977b060628967c92a7737e.jpg: 640x384 1 ambulance, 5.6ms
# image 193/565 /kaggle/working/temp_valid_images/data11-5-_jpg.rf.1dc35975cca11fe0a236ed7b0bd84a2d.jpg: 640x384 1 ambulance, 5.5ms
# image 194/565 /kaggle/working/temp_valid_images/data11-54-_jpg.rf.79d33fbf6cccf7013a1318f5030f620a.jpg: 640x384 1 ambulance, 5.6ms
# image 195/565 /kaggle/working/temp_valid_images/data11-58-_jpg.rf.99ad06684aa60127a06e51597a01ee69.jpg: 640x384 1 ambulance, 5.6ms
# image 196/565 /kaggle/working/temp_valid_images/data11-60-_jpg.rf.842130cf459d83e5892c5e24a4cc2d89.jpg: 640x384 1 ambulance, 5.5ms
# image 197/565 /kaggle/working/temp_valid_images/data11-69-_jpg.rf.81343a8fc23bd1e4432463199a63e49f.jpg: 640x384 1 ambulance, 6.0ms
# image 198/565 /kaggle/working/temp_valid_images/data11-7-_jpg.rf.dcbd4ad749dedb7bfcff27badebe878b.jpg: 640x384 1 ambulance, 6.0ms
# image 199/565 /kaggle/working/temp_valid_images/data11-70-_jpg.rf.65eff6b729eb05c7ee4aa1f0a992ab24.jpg: 640x384 1 ambulance, 5.7ms
# image 200/565 /kaggle/working/temp_valid_images/data11-72-_jpg.rf.213a734e84d428f3ee1481d70edb9276.jpg: 640x384 1 ambulance, 5.5ms
# image 201/565 /kaggle/working/temp_valid_images/data11-74-_jpg.rf.dfc4aa1a8a100a5cd75b9334d352c787.jpg: 640x384 1 ambulance, 6.0ms
# image 202/565 /kaggle/working/temp_valid_images/data12-11-_jpg.rf.dea253bdeeebc9a2fd8d98d3b6eb9055.jpg: 640x384 1 ambulance, 5.6ms
# image 203/565 /kaggle/working/temp_valid_images/data12-13-_jpg.rf.f731c95160238ad7c8d6bf2f93a6fca6.jpg: 640x384 1 ambulance, 5.6ms
# image 204/565 /kaggle/working/temp_valid_images/data12-19-_jpg.rf.dc57fed649c83f4074f29c1a9661bbc3.jpg: 640x384 1 ambulance, 5.4ms
# image 205/565 /kaggle/working/temp_valid_images/data12-20-_jpg.rf.b35f1ea3022e4576698b2742392d55a5.jpg: 640x384 1 ambulance, 5.7ms
# image 206/565 /kaggle/working/temp_valid_images/data12-24-_jpg.rf.13675ffe94a595977ae357a91c889816.jpg: 640x384 1 ambulance, 5.3ms
# image 207/565 /kaggle/working/temp_valid_images/data12-32-_jpg.rf.274571d22d28bdd013e1e701558ffa2e.jpg: 640x384 1 ambulance, 5.8ms
# image 208/565 /kaggle/working/temp_valid_images/data12-34-_jpg.rf.19a2431699e7a39573c4ccb658a762de.jpg: 640x384 1 ambulance, 5.8ms
# image 209/565 /kaggle/working/temp_valid_images/data12-45-_jpg.rf.35f8a7b05f3361218aab2cd1530058bb.jpg: 640x384 1 ambulance, 5.5ms
# image 210/565 /kaggle/working/temp_valid_images/data12-47-_jpg.rf.3818d64615413baf0fb5480e7d012d86.jpg: 640x384 1 ambulance, 5.6ms
# image 211/565 /kaggle/working/temp_valid_images/data12-51-_jpg.rf.f7d04114914df3f806fb604f05b7887f.jpg: 640x384 1 ambulance, 5.4ms
# image 212/565 /kaggle/working/temp_valid_images/data12-56-_jpg.rf.820c86c93b39bc1058ef14b8c9703060.jpg: 640x384 1 ambulance, 5.4ms
# image 213/565 /kaggle/working/temp_valid_images/data12-61-_jpg.rf.52a34ffb5b8b8c5e27405b3bc8bdb7cf.jpg: 640x384 1 ambulance, 5.9ms
# image 214/565 /kaggle/working/temp_valid_images/data12-76-_jpg.rf.2caa67cf73eb94bd6b5b0db4ee452218.jpg: 640x384 1 ambulance, 5.5ms
# image 215/565 /kaggle/working/temp_valid_images/data12-80-_jpg.rf.831bf1978e4f9d1a1f67144e0f6728d0.jpg: 640x384 1 ambulance, 5.7ms
# image 216/565 /kaggle/working/temp_valid_images/data12-86-_jpg.rf.1ac2facb8722756d25d6155be2ffc970.jpg: 640x384 1 ambulance, 5.3ms
# image 217/565 /kaggle/working/temp_valid_images/data12-89-_jpg.rf.f53d248cf11b06fb6941ffc99a3b0fb1.jpg: 640x384 1 ambulance, 5.3ms
# image 218/565 /kaggle/working/temp_valid_images/data13-108-_jpg.rf.248c83353e22966746f7852a16674177.jpg: 640x384 1 ambulance, 5.4ms
# image 219/565 /kaggle/working/temp_valid_images/data13-11-_jpg.rf.bc13f01b32147cb4dad4fe2174533360.jpg: 640x384 1 ambulance, 5.5ms
# image 220/565 /kaggle/working/temp_valid_images/data13-110-_jpg.rf.3857cf3d0a352f3b8d16fdc0777123fa.jpg: 640x384 1 ambulance, 5.2ms
# image 221/565 /kaggle/working/temp_valid_images/data13-117-_jpg.rf.db3c267c15295eb3110fd6beb2cbf717.jpg: 640x384 1 ambulance, 6.1ms
# image 222/565 /kaggle/working/temp_valid_images/data13-120-_jpg.rf.cceacde1511aab4f357be17d94d22072.jpg: 640x384 1 ambulance, 5.3ms
# image 223/565 /kaggle/working/temp_valid_images/data13-124-_jpg.rf.41d205c0167a83c8914e62140d434bca.jpg: 640x384 1 ambulance, 5.4ms
# image 224/565 /kaggle/working/temp_valid_images/data13-13-_jpg.rf.55310a0cbfd040ec64fd1c0e4e5cefe0.jpg: 640x384 1 ambulance, 5.3ms
# image 225/565 /kaggle/working/temp_valid_images/data13-132-_jpg.rf.bb981ea64f73e9066f6765f8db2a3297.jpg: 640x384 1 ambulance, 5.3ms
# image 226/565 /kaggle/working/temp_valid_images/data13-14-_jpg.rf.b2b5c3c217098e2b289f5106ece999ac.jpg: 640x384 1 ambulance, 5.3ms
# image 227/565 /kaggle/working/temp_valid_images/data13-141-_jpg.rf.ece6c935fa8f9a61eded9b2076f30ac7.jpg: 640x384 1 ambulance, 5.5ms
# image 228/565 /kaggle/working/temp_valid_images/data13-148-_jpg.rf.0dadfac1a8659fe84f2ec3e86af523ef.jpg: 640x384 1 ambulance, 5.3ms
# image 229/565 /kaggle/working/temp_valid_images/data13-160-_jpg.rf.597ec4cf9ee7e3bec5c0665cbf07ee5e.jpg: 640x384 1 ambulance, 5.3ms
# image 230/565 /kaggle/working/temp_valid_images/data13-164-_jpg.rf.154d00cad75052045cd1f76c7ffb9362.jpg: 640x384 1 ambulance, 5.3ms
# image 231/565 /kaggle/working/temp_valid_images/data13-167-_jpg.rf.bb7242dae130b74d559a3a9083c40a5f.jpg: 640x384 1 ambulance, 5.3ms
# image 232/565 /kaggle/working/temp_valid_images/data13-172-_jpg.rf.72d17d3dc20dcd41fb6929474b317042.jpg: 640x384 1 ambulance, 5.4ms
# image 233/565 /kaggle/working/temp_valid_images/data13-177-_jpg.rf.76be240109cd90205eae2f2d29cf9c1c.jpg: 640x384 1 ambulance, 6.5ms
# image 234/565 /kaggle/working/temp_valid_images/data13-178-_jpg.rf.fcb63d9ed8f4a6016508d9a47b9563d7.jpg: 640x384 1 ambulance, 5.7ms
# image 235/565 /kaggle/working/temp_valid_images/data13-19-_jpg.rf.24a11839f0705a03a843a32e21d9b19d.jpg: 640x384 2 ambulances, 5.5ms
# image 236/565 /kaggle/working/temp_valid_images/data13-191-_jpg.rf.81d48aeee750073a54ea78bb6ca05b4f.jpg: 640x384 1 ambulance, 5.6ms
# image 237/565 /kaggle/working/temp_valid_images/data13-198-_jpg.rf.99a1e8a5fd2f5216186aa8ec47cef4fb.jpg: 640x384 1 ambulance, 5.7ms
# image 238/565 /kaggle/working/temp_valid_images/data13-31-_jpg.rf.f52db858e77eaaf7e31940e143db02c8.jpg: 640x384 1 ambulance, 6.3ms
# image 239/565 /kaggle/working/temp_valid_images/data13-35-_jpg.rf.af92f6381b95ba368f85dd2b649e360b.jpg: 640x384 1 ambulance, 5.8ms
# image 240/565 /kaggle/working/temp_valid_images/data13-38-_jpg.rf.197e19f18dbd22946b206c962312587d.jpg: 640x384 1 ambulance, 5.5ms
# image 241/565 /kaggle/working/temp_valid_images/data13-39-_jpg.rf.1a4086c0f2ace7b454d7d313a4cf71d4.jpg: 640x384 1 ambulance, 6.0ms
# image 242/565 /kaggle/working/temp_valid_images/data13-40-_jpg.rf.646b0f6523b596b1d905d765f52d3975.jpg: 640x384 1 ambulance, 5.6ms
# image 243/565 /kaggle/working/temp_valid_images/data13-51-_jpg.rf.4d705978f2bcc38455c7c1e3da80f413.jpg: 640x384 1 ambulance, 5.6ms
# image 244/565 /kaggle/working/temp_valid_images/data13-55-_jpg.rf.7fb526f0b06d6174147679056972fb80.jpg: 640x384 1 ambulance, 5.3ms
# image 245/565 /kaggle/working/temp_valid_images/data13-79-_jpg.rf.9eded266b1b69b025421b6b25f920682.jpg: 640x384 1 ambulance, 5.4ms
# image 246/565 /kaggle/working/temp_valid_images/data13-80-_jpg.rf.12a5e64e40f1eb23dde59b6bf2d043ea.jpg: 640x384 1 ambulance, 5.4ms
# image 247/565 /kaggle/working/temp_valid_images/data13-96-_jpg.rf.aa6628d33bc8c3cc8cd5625ba0f2f7c4.jpg: 640x384 1 ambulance, 5.4ms
# image 248/565 /kaggle/working/temp_valid_images/data14-101-_jpg.rf.b8e16940bee1a585eccf7d050f8d42ef.jpg: 640x384 1 ambulance, 1 police, 5.7ms
# image 249/565 /kaggle/working/temp_valid_images/data14-104-_jpg.rf.f3ec301d4b0c85a719e77d8687e073be.jpg: 640x384 1 ambulance, 5.5ms
# image 250/565 /kaggle/working/temp_valid_images/data14-106-_jpg.rf.c1e39ab340ebe073c0fe0920f73254af.jpg: 640x384 1 ambulance, 5.7ms
# image 251/565 /kaggle/working/temp_valid_images/data14-107-_jpg.rf.48d08a35642fc1be376b873036b6f24f.jpg: 640x384 1 ambulance, 5.5ms
# image 252/565 /kaggle/working/temp_valid_images/data14-111-_jpg.rf.2d5af0948bf52c7225cfd6e5fae2d267.jpg: 640x384 1 ambulance, 5.4ms
# image 253/565 /kaggle/working/temp_valid_images/data14-120-_jpg.rf.b43d1987ad6c24ca4d69dd3af2565ebb.jpg: 640x384 2 ambulances, 5.9ms
# image 254/565 /kaggle/working/temp_valid_images/data14-125-_jpg.rf.adac992697410efab615ffa26a306795.jpg: 640x384 1 ambulance, 5.7ms
# image 255/565 /kaggle/working/temp_valid_images/data14-140-_jpg.rf.42d192be8aaf595a9269100651f200dc.jpg: 640x384 1 ambulance, 5.6ms
# image 256/565 /kaggle/working/temp_valid_images/data14-142-_jpg.rf.a247d78864d0eacf5ff5b9774ddc02ba.jpg: 640x384 1 ambulance, 5.4ms
# image 257/565 /kaggle/working/temp_valid_images/data14-143-_jpg.rf.52957738a432baa53783ac47bfd4b671.jpg: 640x384 1 ambulance, 5.5ms
# image 258/565 /kaggle/working/temp_valid_images/data14-18-_jpg.rf.7b3d037482c5e1f9102acfd7945d0758.jpg: 640x384 1 ambulance, 1 police, 5.3ms
# image 259/565 /kaggle/working/temp_valid_images/data14-19-_jpg.rf.10454b7db38c9c9eb0f81d80056d771b.jpg: 640x384 1 ambulance, 1 police, 5.4ms
# image 260/565 /kaggle/working/temp_valid_images/data14-22-_jpg.rf.7916ab653c321cd561df8fe3e64bf6b3.jpg: 640x384 1 police, 5.4ms
# image 261/565 /kaggle/working/temp_valid_images/data14-25-_jpg.rf.f7843e5cf499ace6e18aab4676e5d017.jpg: 640x384 1 police, 5.5ms
# image 262/565 /kaggle/working/temp_valid_images/data14-26-_jpg.rf.79e6e436c397bc8b6acbb0b07fe86e0c.jpg: 640x384 1 police, 5.3ms
# image 263/565 /kaggle/working/temp_valid_images/data14-32-_jpg.rf.94a3471ee7c7e676947c916c5ce2d63e.jpg: 640x384 1 police, 5.4ms
# image 264/565 /kaggle/working/temp_valid_images/data14-39-_jpg.rf.a0fee91d8f500193e2db2729455dbf3c.jpg: 640x384 1 police, 5.6ms
# image 265/565 /kaggle/working/temp_valid_images/data14-42-_jpg.rf.d5ce4d03ff6b17b333965b2838aca79e.jpg: 640x384 1 police, 5.3ms
# image 266/565 /kaggle/working/temp_valid_images/data14-43-_jpg.rf.7dbf6cfc106ca463f4ce0f32a42fb8f4.jpg: 640x384 1 police, 5.6ms
# image 267/565 /kaggle/working/temp_valid_images/data14-5-_jpg.rf.6972fd783b10ddb2ce1d17b87005ad7b.jpg: 640x384 1 police, 5.4ms
# image 268/565 /kaggle/working/temp_valid_images/data14-52-_jpg.rf.7d80ca6faafd8dcef68853fd28024cba.jpg: 640x384 1 ambulance, 5.3ms
# image 269/565 /kaggle/working/temp_valid_images/data14-55-_jpg.rf.80c54d353f5cb81d72ccf83df6b3cea4.jpg: 640x384 1 ambulance, 5.3ms
# image 270/565 /kaggle/working/temp_valid_images/data14-60-_jpg.rf.6cb8f0bdb9050bd4b89048dfd627cfb8.jpg: 640x384 1 ambulance, 5.5ms
# image 271/565 /kaggle/working/temp_valid_images/data14-64-_jpg.rf.811669b39df717e678b36c68eb97ed1b.jpg: 640x384 1 ambulance, 5.5ms
# image 272/565 /kaggle/working/temp_valid_images/data14-65-_jpg.rf.fc2b83836c8f8e242d848ef6ac33b931.jpg: 640x384 1 ambulance, 5.4ms
# image 273/565 /kaggle/working/temp_valid_images/data14-68-_jpg.rf.d74cad0c891a4100de944ad3c1d91198.jpg: 640x384 1 ambulance, 1 police, 5.3ms
# image 274/565 /kaggle/working/temp_valid_images/data14-78-_jpg.rf.4eaf3a01ab0f3b334da136f36e0ceec4.jpg: 640x384 1 ambulance, 5.8ms
# image 275/565 /kaggle/working/temp_valid_images/data14-87-_jpg.rf.426b362e090751011ddbce52abfaedc9.jpg: 640x384 1 police, 5.4ms
# image 276/565 /kaggle/working/temp_valid_images/data14-96-_jpg.rf.829e4727f59173f0d66a7f1ea8f8176c.jpg: 640x384 1 police, 5.5ms
# image 277/565 /kaggle/working/temp_valid_images/data15-104-_jpg.rf.1426153b4a9b19bf195e04b87e37de1d.jpg: 640x384 1 ambulance, 5.3ms
# image 278/565 /kaggle/working/temp_valid_images/data15-113-_jpg.rf.c98fc55785f3d4e1195d69eb85b9b250.jpg: 640x384 1 ambulance, 6.3ms
# image 279/565 /kaggle/working/temp_valid_images/data15-114-_jpg.rf.6f798c44b42a3b36c92ebd04dd4a4679.jpg: 640x384 1 ambulance, 5.8ms
# image 280/565 /kaggle/working/temp_valid_images/data15-118-_jpg.rf.684ae567360917208077fc0b1772cb4a.jpg: 640x384 1 ambulance, 5.5ms
# image 281/565 /kaggle/working/temp_valid_images/data15-119-_jpg.rf.64045d04da12e635390ed4efd5632fe4.jpg: 640x384 1 ambulance, 5.3ms
# image 282/565 /kaggle/working/temp_valid_images/data15-12-_jpg.rf.70c95b676c94324301a3c4b4ea699744.jpg: 640x384 1 ambulance, 5.3ms
# image 283/565 /kaggle/working/temp_valid_images/data15-131-_jpg.rf.a9e5e48319094460b486d3bcdb27c015.jpg: 640x384 1 ambulance, 5.3ms
# image 284/565 /kaggle/working/temp_valid_images/data15-134-_jpg.rf.70ba290915a601fa3989f348420d610c.jpg: 640x384 1 ambulance, 5.6ms
# image 285/565 /kaggle/working/temp_valid_images/data15-147-_jpg.rf.ea5f702228add04efe3c270feb3e22e4.jpg: 640x384 1 ambulance, 5.4ms
# image 286/565 /kaggle/working/temp_valid_images/data15-159-_jpg.rf.cb53aba6e412b3340678640d1650d429.jpg: 640x384 1 ambulance, 5.5ms
# image 287/565 /kaggle/working/temp_valid_images/data15-163-_jpg.rf.863e2d02ae37da06bce3d5f5085b4e21.jpg: 640x384 1 ambulance, 5.4ms
# image 288/565 /kaggle/working/temp_valid_images/data15-166-_jpg.rf.4406032db59aa8d6b201a17ef72988e5.jpg: 640x384 1 ambulance, 5.3ms
# image 289/565 /kaggle/working/temp_valid_images/data15-172-_jpg.rf.d97910c6e61793f501fee8d7a77b8019.jpg: 640x384 2 ambulances, 5.5ms
# image 290/565 /kaggle/working/temp_valid_images/data15-197-_jpg.rf.1688952fd9557830d11d66670e8f7fa3.jpg: 640x384 1 ambulance, 5.4ms
# image 291/565 /kaggle/working/temp_valid_images/data15-2-_jpg.rf.9a0bbf6da1f784886d693ac977410d96.jpg: 640x384 1 ambulance, 6.1ms
# image 292/565 /kaggle/working/temp_valid_images/data15-20-_jpg.rf.d3d15523faa5323561f484513135cb24.jpg: 640x384 1 ambulance, 5.3ms
# image 293/565 /kaggle/working/temp_valid_images/data15-23-_jpg.rf.248191ad25dc3d3c1e4d87fe67604c1f.jpg: 640x384 1 ambulance, 5.7ms
# image 294/565 /kaggle/working/temp_valid_images/data15-31-_jpg.rf.d0fbf4492737a0489cdfd0a5744ea838.jpg: 640x384 1 ambulance, 5.4ms
# image 295/565 /kaggle/working/temp_valid_images/data15-33-_jpg.rf.cb291ade70dc7ce6da1a220af51b66b0.jpg: 640x384 1 ambulance, 5.3ms
# image 296/565 /kaggle/working/temp_valid_images/data15-36-_jpg.rf.8968fe7fbe0eb745b280adf556a1fdd2.jpg: 640x384 1 ambulance, 5.3ms
# image 297/565 /kaggle/working/temp_valid_images/data15-42-_jpg.rf.86c9af69f648506fad629e2a70431888.jpg: 640x384 1 ambulance, 5.7ms
# image 298/565 /kaggle/working/temp_valid_images/data15-51-_jpg.rf.198c539a9f7299b9673738a32f6df19a.jpg: 640x384 1 ambulance, 5.7ms
# image 299/565 /kaggle/working/temp_valid_images/data15-7-_jpg.rf.683eb3d217110694e032d25d10691efb.jpg: 640x384 1 ambulance, 5.6ms
# image 300/565 /kaggle/working/temp_valid_images/data15-71-_jpg.rf.edc338a81fa5ff31adcb83890931e57d.jpg: 640x384 1 ambulance, 5.5ms
# image 301/565 /kaggle/working/temp_valid_images/data15-72-_jpg.rf.2bb972c9c379c563d9bd236ff994f387.jpg: 640x384 1 ambulance, 5.8ms
# image 302/565 /kaggle/working/temp_valid_images/data15-79-_jpg.rf.011df4abda27adaa5fc33008bab44292.jpg: 640x384 1 ambulance, 5.8ms
# image 303/565 /kaggle/working/temp_valid_images/data15-8-_jpg.rf.d3528afa1e1fcac66dbbd1e3f6a0872e.jpg: 640x384 1 ambulance, 5.9ms
# image 304/565 /kaggle/working/temp_valid_images/data15-84-_jpg.rf.3b2a93c894c0bed2f8c144d31661b8aa.jpg: 640x384 1 ambulance, 5.4ms
# image 305/565 /kaggle/working/temp_valid_images/data15-85-_jpg.rf.bfbfa3b5ba7d2959e1b5cfc1dda3b145.jpg: 640x384 1 ambulance, 5.4ms
# image 306/565 /kaggle/working/temp_valid_images/data15-91-_jpg.rf.e0a3490fcc96ef40acf6327644091a52.jpg: 640x384 1 ambulance, 6.1ms
# image 307/565 /kaggle/working/temp_valid_images/data15-96-_jpg.rf.595defc187a1425b1181a08d4d489263.jpg: 640x384 1 ambulance, 5.9ms
# image 308/565 /kaggle/working/temp_valid_images/data15-99-_jpg.rf.e6d6b72d00197d7b68b9cbb98ea94855.jpg: 640x384 1 ambulance, 5.6ms
# image 309/565 /kaggle/working/temp_valid_images/data16-10-_jpg.rf.60710177c7fb8f66af190c8fd78bfd1c.jpg: 384x640 1 ambulance, 6.2ms
# image 310/565 /kaggle/working/temp_valid_images/data16-101-_jpg.rf.54dea871f9c52136a1f1f601671a4b2e.jpg: 384x640 1 ambulance, 5.9ms
# image 311/565 /kaggle/working/temp_valid_images/data16-109-_jpg.rf.de94c23b5717bee8a6e845046195848e.jpg: 384x640 1 ambulance, 6.3ms
# image 312/565 /kaggle/working/temp_valid_images/data16-112-_jpg.rf.5094d71a76414097abb4032ba55da303.jpg: 384x640 1 ambulance, 5.9ms
# image 313/565 /kaggle/working/temp_valid_images/data16-117-_jpg.rf.c8bad40fff59120493a63bf454afbde5.jpg: 384x640 1 ambulance, 5.8ms
# image 314/565 /kaggle/working/temp_valid_images/data16-118-_jpg.rf.eba9d4fb5ddfd8a0c729e5f8a5921498.jpg: 384x640 1 ambulance, 5.9ms
# image 315/565 /kaggle/working/temp_valid_images/data16-122-_jpg.rf.457ee9d0b59610266172cc85e4805f2d.jpg: 384x640 1 ambulance, 6.7ms
# image 316/565 /kaggle/working/temp_valid_images/data16-124-_jpg.rf.88aec7e6f6df87fa52bf1b99cb257c95.jpg: 384x640 1 ambulance, 6.6ms
# image 317/565 /kaggle/working/temp_valid_images/data16-125-_jpg.rf.40e87d7626a0153a000b7c69d6b1aed3.jpg: 384x640 2 ambulances, 6.3ms
# image 318/565 /kaggle/working/temp_valid_images/data16-126-_jpg.rf.07e9e79a034e325b42dcb42e927591c3.jpg: 384x640 1 ambulance, 6.4ms
# image 319/565 /kaggle/working/temp_valid_images/data16-13-_jpg.rf.4921ee94a36b3246857e0de6b682da5e.jpg: 384x640 1 ambulance, 6.5ms
# image 320/565 /kaggle/working/temp_valid_images/data16-146-_jpg.rf.a4a61fbd9a7a6dc821701c0e0d010758.jpg: 384x640 1 ambulance, 6.1ms
# image 321/565 /kaggle/working/temp_valid_images/data16-147-_jpg.rf.b61dfb943c0fd5de2ca811edd012ba86.jpg: 384x640 1 ambulance, 6.5ms
# image 322/565 /kaggle/working/temp_valid_images/data16-148-_jpg.rf.4144397145434fdc0bc4c6f470a0d5b0.jpg: 384x640 1 ambulance, 6.8ms
# image 323/565 /kaggle/working/temp_valid_images/data16-15-_jpg.rf.280fff8f7b80882d882bf2b21ec94ac2.jpg: 384x640 1 ambulance, 6.5ms
# image 324/565 /kaggle/working/temp_valid_images/data16-155-_jpg.rf.c75a6ef439a3ef1b4079e2dc31a10b82.jpg: 384x640 (no detections), 6.4ms
# image 325/565 /kaggle/working/temp_valid_images/data16-17-_jpg.rf.e1efd9fccbede9247503b3a22866f1d1.jpg: 384x640 1 ambulance, 6.2ms
# image 326/565 /kaggle/working/temp_valid_images/data16-32-_jpg.rf.0c53c44adf1fd3d3e2a094757c3716cc.jpg: 384x640 1 ambulance, 6.1ms
# image 327/565 /kaggle/working/temp_valid_images/data16-38-_jpg.rf.8050f36dd245e673e8f2b051c9385cff.jpg: 384x640 1 ambulance, 6.0ms
# image 328/565 /kaggle/working/temp_valid_images/data16-40-_jpg.rf.2db6a874144a9909e06b6159b1d650be.jpg: 384x640 1 ambulance, 6.3ms
# image 329/565 /kaggle/working/temp_valid_images/data16-48-_jpg.rf.bce3b23e921469d48914e185983ff6ad.jpg: 384x640 1 ambulance, 6.1ms
# image 330/565 /kaggle/working/temp_valid_images/data16-66-_jpg.rf.b4c61c11d7a817089d3334bb75079580.jpg: 384x640 2 ambulances, 6.2ms
# image 331/565 /kaggle/working/temp_valid_images/data16-67-_jpg.rf.8d9cac34e8060f1339436518ff6129dc.jpg: 384x640 2 ambulances, 6.3ms
# image 332/565 /kaggle/working/temp_valid_images/data16-74-_jpg.rf.20765db80a753c9b5b2796194365079d.jpg: 384x640 2 ambulances, 6.2ms
# image 333/565 /kaggle/working/temp_valid_images/data16-77-_jpg.rf.2eaec35c57fa1b1f56e8c4dcef22814b.jpg: 384x640 1 ambulance, 6.0ms
# image 334/565 /kaggle/working/temp_valid_images/data16-80-_jpg.rf.4690250515f60769292d35cd3711c9de.jpg: 384x640 1 ambulance, 5.9ms
# image 335/565 /kaggle/working/temp_valid_images/data16-82-_jpg.rf.c462f868acaa397d2b01ef7efdfb6599.jpg: 384x640 1 ambulance, 6.0ms
# image 336/565 /kaggle/working/temp_valid_images/data16-86-_jpg.rf.65bc0fac25cba36094a829b3d2c9605b.jpg: 384x640 2 ambulances, 6.0ms
# image 337/565 /kaggle/working/temp_valid_images/data16-87-_jpg.rf.ce45f16f8d3f6a49d9cefc93880120db.jpg: 384x640 1 ambulance, 6.1ms
# image 338/565 /kaggle/working/temp_valid_images/data16-88-_jpg.rf.c190a88f0b342b41278ca3c98fff59ce.jpg: 384x640 1 ambulance, 6.2ms
# image 339/565 /kaggle/working/temp_valid_images/data16-99-_jpg.rf.955857d0bf11104552d1a0648ec275ba.jpg: 384x640 1 ambulance, 6.0ms
# image 340/565 /kaggle/working/temp_valid_images/data17-101-_jpg.rf.cd5ed3e08b52f563d05acc8d1f8db264.jpg: 640x384 1 ambulance, 6.9ms
# image 341/565 /kaggle/working/temp_valid_images/data17-113-_jpg.rf.328286940ea31933e07555a39a6afd37.jpg: 640x384 1 ambulance, 6.6ms
# image 342/565 /kaggle/working/temp_valid_images/data17-121-_jpg.rf.f85490879941d09941fd25e6243ab260.jpg: 640x384 1 ambulance, 6.4ms
# image 343/565 /kaggle/working/temp_valid_images/data17-123-_jpg.rf.6419b66cb6f6d40fe94fe52f7e5de067.jpg: 640x384 1 ambulance, 5.9ms
# image 344/565 /kaggle/working/temp_valid_images/data17-125-_jpg.rf.f696386984ed24099de5b0b30f3e9454.jpg: 640x384 1 ambulance, 6.0ms
# image 345/565 /kaggle/working/temp_valid_images/data17-127-_jpg.rf.a7b0820b7efc91c169e8287529c8b8f8.jpg: 640x384 1 ambulance, 6.0ms
# image 346/565 /kaggle/working/temp_valid_images/data17-139-_jpg.rf.b569142db4e39ea105197c378b4bb1db.jpg: 640x384 1 ambulance, 6.4ms
# image 347/565 /kaggle/working/temp_valid_images/data17-148-_jpg.rf.51c04f290e04c3f50480917c661c0a74.jpg: 640x384 1 ambulance, 5.7ms
# image 348/565 /kaggle/working/temp_valid_images/data17-153-_jpg.rf.3f375cede10aaa3ff640c434d74d2b84.jpg: 640x384 1 ambulance, 5.8ms
# image 349/565 /kaggle/working/temp_valid_images/data17-157-_jpg.rf.4cd6ec522b0333bfc4490bb858761836.jpg: 640x384 1 ambulance, 5.8ms
# image 350/565 /kaggle/working/temp_valid_images/data17-159-_jpg.rf.61898c5ac5a944f7ca98bc96410fde70.jpg: 640x384 1 ambulance, 5.9ms
# image 351/565 /kaggle/working/temp_valid_images/data17-168-_jpg.rf.84e7a7597014fa20b17976e8ea66f3a7.jpg: 640x384 1 ambulance, 5.8ms
# ...
# ❌ Error displaying data2-92-_jpg.rf.320b6289fa0955270fb265121e473ca0.jpg: list index out of range
# ❌ Error displaying data2-96-_jpg.rf.f4b96cbab28b65c18e7de86e4946e23f.jpg: list index out of range
# ❌ Error displaying data21-104-_jpg.rf.8114268870fbd9bbf24e4a68ba12fea0.jpg: list index out of range
# ❌ Error displaying data21-110-_jpg.rf.867902a462a326b071f17888bcd01af8.jpg: list index out of range
# ❌ Error displaying data21-113-_jpg.rf.0855402d4c6cc57d8ac26309c0c147fc.jpg: list index out of range
# ❌ Error displaying data21-116-_jpg.rf.289fa505f99c8af9235ae5cfb40994ba.jpg: list index out of range
# ❌ Error displaying data21-118-_jpg.rf.64a983f5183181b58dc696a11ce0c3c1.jpg: list index out of range
# ❌ Error displaying data21-125-_jpg.rf.fd88061acc4d18302488c06d2900f2d9.jpg: list index out of range
# ❌ Error displaying data21-130-_jpg.rf.2bd11ba11a9628cb4e14f30c1785d9f5.jpg: list index out of range
# ❌ Error displaying data9-155-_jpg.rf.f9597f0faf6ce610a644b57cd73f3e38.jpg: list index out of range
# ❌ Error displaying data9-156-_jpg.rf.9de3fad504b1d2c562ea97df082b74cb.jpg: list index out of range
# ❌ Error displaying data9-18-_jpg.rf.98dd4ccd73949405f0e3af238f5391ef.jpg: list index out of range
# ❌ Error displaying data9-21-_jpg.rf.646e4f741aefe07168bfd537d736e2f1.jpg: list index out of range
# ❌ Error displaying data9-26-_jpg.rf.7f7095cf0a4ab134526db1b24596b690.jpg: list index out of range
# ❌ Error displaying data9-28-_jpg.rf.d2d9c26dfc0b50bd08230625e3a07b26.jpg: list index out of range
# ❌ Error displaying data9-3-_jpg.rf.b9b15af07a2d4cc995e80a525e736073.jpg: list index out of range
# ❌ Error displaying data9-33-_jpg.rf.2dfc44298b8042bf7ef6f49369e271f1.jpg: list index out of range
# ❌ Error displaying data9-34-_jpg.rf.ccc3a961c1bd0136a5deaa649c311cfb.jpg: list index out of range
# ❌ Error displaying data9-35-_jpg.rf.b2d8e9f1aed2cdacbc762023e5e92e67.jpg: list index out of range
# ❌ Error displaying data9-42-_jpg.rf.acccf0484b8938cc0edc2a3dd4823493.jpg: list index out of range
# ❌ Error displaying data9-50-_jpg.rf.0a4f7f1bb9b8de4bb73d650d1b11e2be.jpg: list index out of range
# ❌ Error displaying data9-56-_jpg.rf.19f136150963c37b9e13e702f44f6745.jpg: list index out of range
# ❌ Error displaying data9-58-_jpg.rf.b15606aa0a8c624149005e16b03cba28.jpg: list index out of range
# ❌ Error displaying data9-61-_jpg.rf.05a1e26e0cd00c075a601141141a752c.jpg: list index out of range
# ❌ Error displaying data9-64-_jpg.rf.e6fd512e99c80b0213e2dca1630eddff.jpg: list index out of range
# ❌ Error displaying data9-66-_jpg.rf.4713e2a615e62d41bd033378648fe023.jpg: list index out of range
# ❌ Error displaying data9-70-_jpg.rf.575d2729a898653ada5cb0f416e3c987.jpg: list index out of range
# ❌ Error displaying data9-71-_jpg.rf.6cd7eb67e6883d2f436e1b2ff56c285e.jpg: list index out of range
# ❌ Error displaying data9-77-_jpg.rf.326586a654144c9f35c78ac3d4763d34.jpg: list index out of range
# ❌ Error displaying data9-8-_jpg.rf.4b8494524cf483e01bbfce7a01ef23cd.jpg: list index out of range
# ❌ Error displaying data9-97-_jpg.rf.94184b1caaa7b1b947ccba0bd81732ba.jpg: list index out of range
# ❌ Error displaying e71dabff-3c72-417a-b64d-a9dc3531fbe7_jpg.rf.d8972fab75f3c3e815747c6ea8a3d960.jpg: too many values to unpack (expected 5)
# ❌ Error displaying e8761f98-b7db-4fa6-bec3-4a7854f7953e_jpg.rf.7fce216dae7c060a8cd27dd6ad81d0e2.jpg: too many values to unpack (expected 5)
# ❌ Error displaying ee3019be-b7e7-4bfe-b1c1-aac7df78e88d_png.rf.73c4f408403ce5b00489cb8e65274aca.jpg: list index out of range
# ❌ Error displaying eedb0358-b83e-47e0-87b5-e6650bca503b_jpg.rf.79fc220989ca0824613407806a5e797e.jpg: too many values to unpack (expected 5)
# ❌ Error displaying stock-photo-police-car-in-the-city-at-night-2472270831_jpg.rf.4745c97651bea504ae77d29d37a72c89.jpg: too many values to unpack (expected 5)
# ❌ Error displaying stock-photo-thrissur-kerala-india-group-of-special-ambulance-for-covid-patients-in-kerala-1866224857_jpg.rf.c19a577b2b533c076d84cc3c37dd834b.jpg: too many values to unpack (expected 5)
# ❌ Error displaying stock-photo-varanasi-india-november-view-of-ambulance-rolling-in-the-streets-of-varanasi-in-the-1226841316_jpg.rf.a00995877093a05ddf14a3ff1e2a24d6.jpg: too many values to unpack (expected 5)
#
# ============================================================
# COMPLETE!
# ============================================================
# ✅ Displayed 0 image comparisons
# 📁 All predictions saved to: /kaggle/working/runs/detect/predict/
# 🗑️ Temporary images in: /kaggle/working/temp_valid_images
#
# 💡 TIP: If successful, run predictions on all images:
#    results = model.predict(source='/kaggle/working/temp_valid_images', conf=0.25, save=True)

# %%
import shutil
import os

def create_zip_backup(source_folder, zip_name='runs_backup'):
    """Create zip file with size information"""
    
    # Check if source exists
    if not os.path.exists(source_folder):
        print(f"❌ Folder not found: {source_folder}")
        return None
    
    # Get folder size before zipping
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(source_folder):
        for f in filenames:
            fp = os.path.join(dirpath, f)
            if os.path.exists(fp):
                total_size += os.path.getsize(fp)
    
    print(f"📁 Original folder size: {total_size / (1024*1024):.2f} MB")
    print(f"🗜️  Creating zip file...")
    
    # Create zip
    zip_path = f'/kaggle/working/{zip_name}'
    shutil.make_archive(zip_path, 'zip', source_folder)
    
    # Show results
    zip_file = f'{zip_path}.zip'
    zip_size = os.path.getsize(zip_file)
    compression_ratio = (1 - zip_size/total_size) * 100
    
    print(f"✅ Zip created: {zip_file}")
    print(f"📦 Zip size: {zip_size / (1024*1024):.2f} MB")
    print(f"💾 Compression: {compression_ratio:.1f}%")
    
    return zip_file

# Create the zip
zip_file = create_zip_backup('/kaggle/working/runs', 'runs_backup')

# Show download link
if zip_file:
    from IPython.display import FileLink
    print("\n📥 Click below to download:")
    display(FileLink(zip_file))

# %%
import shutil
import os

def create_zip_backup(source_folder, zip_name='temp_valid_imagesbackup'):
    """Create zip file with size information"""
    
    # Check if source exists
    if not os.path.exists(source_folder):
        print(f"❌ Folder not found: {source_folder}")
        return None
    
    # Get folder size before zipping
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(source_folder):
        for f in filenames:
            fp = os.path.join(dirpath, f)
            if os.path.exists(fp):
                total_size += os.path.getsize(fp)
    
    print(f"📁 Original folder size: {total_size / (1024*1024):.2f} MB")
    print(f"🗜️  Creating zip file...")
    
    # Create zip
    zip_path = f'/kaggle/working/{zip_name}'
    shutil.make_archive(zip_path, 'zip', source_folder)
    
    # Show results
    zip_file = f'{zip_path}.zip'
    zip_size = os.path.getsize(zip_file)
    compression_ratio = (1 - zip_size/total_size) * 100
    
    print(f"✅ Zip created: {zip_file}")
    print(f"📦 Zip size: {zip_size / (1024*1024):.2f} MB")
    print(f"💾 Compression: {compression_ratio:.1f}%")
    
    return zip_file

# Create the zip
zip_file = create_zip_backup('/kaggle/working/temp_valid_images', 'temp_valid_imagesbackup')

# Show download link
if zip_file:
    from IPython.display import FileLink
    print("\n📥 Click below to download:")
    display(FileLink(zip_file))
